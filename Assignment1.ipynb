# %% [markdown]
# # Context-sensitive Spelling Correction
#
# The goal of the assignment is to implement context-sensitive spelling correction. The input of the code will be a set of text lines and the output will be the same lines with spelling mistakes fixed.
#
# Submit the solution of the assignment to Moodle as a link to your GitHub repository containing this notebook.
#
# Useful links:
# - [Norvig's solution](https://norvig.com/spell-correct.html)
# - [Norvig's dataset](https://norvig.com/big.txt)
# - [Ngrams data](https://www.ngrams.info/download_coca.asp)
#
# Grading:
# - 60 points - Implement spelling correction
# - 20 points - Justify your decisions
# - 20 points - Evaluate on a test set

# %% [markdown]
# ## Implement context-sensitive spelling correction
#
# Your task is to implement context-sensitive spelling corrector using N-gram language model. The idea is to compute conditional probabilities of possible correction options. For example, the phrase "dking sport" should be fixed as "doing sport" not "dying sport", while "dking species" -- as "dying species".
#
# The best way to start is to analyze [Norvig's solution](https://norvig.com/spell-correct.html) and [N-gram Language Models](https://web.stanford.edu/~jurafsky/slp3/3.pdf).
#
# When solving this task, we expect you'll face (and successfully deal with) some problems or make up the ideas of the model improvement. Some of them are:
#
# - solving a problem of n-grams frequencies storing for a large corpus;
# - taking into account keyboard layout and associated misspellings;
# - efficiency improvement to make the solution faster;
# - ...
#
# Please don't forget to describe such cases, and what you decided to do with them, in the Justification section.
#
# ##### IMPORTANT:
# Your project should not be a mere code copy-paste from somewhere. You must provide:
# - Your implementation
# - Analysis of why the implemented approach is suggested
# - Improvements of the original approach that you have chosen to implement

# %% [markdown]
# # Short introduction

# %% [markdown]
# At the beginning of the assignment I had an idea about using CBOW model as a main solution algorithm. It was about using CBOW weights in order to predict the misspelled word based on its context words and then comparing it to correction candidates. However, the idea failed miserably not even reaching the baseline level of Norvig's super simple frequency-based implementation. I spent around 3 full days trying to make it work(some solutions were crazy enough to send me to the asylum) and had quite a lot of fun with it, but then just used a BERT model instead and got a much better accuracy after writing code for just a couple of hours. I am not sure if you are interested in an awful word2vec implementation, but I will share it anyway)

# %% [markdown]
# # Baseline N-gram solution

# %%
import re
import collections
from itertools import islice
from typing import List, Set, Dict

class NGramSpellingCorrector:
    def __init__(self, corpus_file, n):
        self.n = n 
        self.words = self.load_corpus(corpus_file)
        self.vocab = set(self.words)
        self.word_freqs = collections.Counter(self.words)
        self.ngrams = self.build_ngrams(self.words, n)

    def load_corpus(self, corpus_file):
        with open(corpus_file, "r", encoding="utf-8") as f:
            text = f.read().lower()
        return re.findall(r'\w+', text)

    def build_ngrams(self, words, n):
        ngram_model = collections.defaultdict(set)
        for i in range(len(words) - n + 1):
            context = tuple(words[i:i + n - 1]) 
            next_word = words[i + n - 1]
            ngram_model[context].add(next_word)
        return ngram_model

    def known(self, words):
        return {w for w in words if w in self.vocab}

    def edits1(self, word):
        letters = 'abcdefghijklmnopqrstuvwxyz'
        splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
        deletes = {L + R[1:] for L, R in splits if R}
        transposes = {L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1}
        replaces = {L + c + R[1:] for L, R in splits if R for c in letters}
        inserts = {L + c + R for L, R in splits for c in letters}
        return set(deletes | transposes | replaces | inserts)

    def edits2(self, word):
        return {e2 for e1 in self.edits1(word) for e2 in self.edits1(e1)}

    def candidates(self, word, context):
        return (self.known([word]) or
                self.known(self.edits1(word)) or
                self.known(self.edits2(word)) or
                {word})

    def probability(self, word):
        return self.word_freqs[word] / sum(self.word_freqs.values())

    def correct(self, word, context):
        candidates = self.candidates(word, context)
        
        if not context:
            return max(candidates, key=self.probability)
        
        context_tuple = tuple(context[-(self.n - 1):])
        possible_words = self.ngrams.get(context_tuple, set())
        valid_candidates = candidates & possible_words
    
        return max(valid_candidates or candidates, key=self.probability)

# %%
def load_eval_dataset(file_path="eval.txt"):
    data = []
    
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split('|')
            if len(parts) != 3:
                continue
            
            sentence, misspelled, correct = parts
            words = sentence.split()
            
            if misspelled in words:
                words.remove(misspelled)
            
            data.append({
                'sentence': sentence,
                'misspelled': misspelled,
                'correct': correct,
                'context': words
            })
    
    return data

def evaluate_model(model, eval_data):
    correct = 0
    total = 0
    
    for case in eval_data:
        predicted = model.correct(case['misspelled'], case['context'])
        print(f"Sentence: {case['sentence']} | Predicted: {predicted} | Correct: {case['correct']}")
        
        total += 1
        if predicted == case['correct']:
            correct += 1

    overall_accuracy = correct / total if total > 0 else 0
    
    print(f"\n{' Overall Accuracy ':-^40}")
    print(f"{correct}/{total} ({overall_accuracy:.2%})\n")

if __name__ == "__main__":
    corpus_path = "/kaggle/input/big-text/big.txt"
    eval_file_path = "/kaggle/input/eval-ambiguous/eval.txt"

    corrector = NGramSpellingCorrector(corpus_path, n=3)
    eval_data = load_eval_dataset(eval_file_path)
    evaluate_model(corrector, eval_data)
# Out:
# Sentence: The car drve fast on the highway. | Predicted: drove | Correct: drove
# Sentence: She saw a brid flying in the sky. | Predicted: rid | Correct: bird
# Sentence: He used a pencl to write notes. | Predicted: pencil | Correct: pencil
# Sentence: They found a brwn puppy in the park. | Predicted: brown | Correct: brown
# Sentence: My friend brke his phone screen. | Predicted: broke | Correct: broke
# Sentence: The dog dug a hol in the yard. | Predicted: how | Correct: hole
# Sentence: She wore a yelow dress to the party. | Predicted: below | Correct: yellow
# Sentence: I heard a lod noise outside. | Predicted: old | Correct: loud
# Sentence: The old man had a wlk in the garden. | Predicted: walk | Correct: walk
# Sentence: We took a bote to the island. | Predicted: bone | Correct: boat
# Sentence: His glss broke when it fell. | Predicted: glass | Correct: glass
# Sentence: She drew a smal picture in her notebook. | Predicted: small | Correct: small
# Sentence: The fire brnt the wood completely. | Predicted: bent | Correct: burnt
# Sentence: The child liks to play in the park. | Predicted: like | Correct: likes
# Sentence: She had a hrd time solving the puzzle. | Predicted: had | Correct: hard
# Sentence: The storm clsed all the roads. | Predicted: closed | Correct: closed
# Sentence: We saw a bwl of fruit on the table. | Predicted: bowl | Correct: bowl
# Sentence: She put a buk on the shelf. | Predicted: but | Correct: book
# Sentence: The cat jumpd onto the windowsill. | Predicted: jumped | Correct: jumped
# Sentence: He set the clock to wke him early. | Predicted: we | Correct: wake
# Sentence: They sent a lter to their cousin. | Predicted: later | Correct: letter
# Sentence: I ate a bow of soup for lunch. | Predicted: bow | Correct: bowl
# Sentence: He left his cke on the table. | Predicted: ce | Correct: cake
# Sentence: She saw a bech covered in seashells. | Predicted: bench | Correct: beach
# Sentence: The child clmbed the tree. | Predicted: climbed | Correct: climbed
# Sentence: He spent his evning watching TV. | Predicted: evening | Correct: evening
# Sentence: She made a brad sandwich. | Predicted: bad | Correct: bread
# Sentence: The baby crwed across the floor. | Predicted: cried | Correct: crawled
# Sentence: The kite flw high in the sky. | Predicted: few | Correct: flew
# Sentence: They saw a bule fish in the lake. | Predicted: blue | Correct: blue
# Sentence: His wrst was hurting after the fall. | Predicted: west | Correct: wrist
# Sentence: The teacher gave a qiz today. | Predicted: wiz | Correct: quiz
# Sentence: She wore a shrt jacket in the cold. | Predicted: short | Correct: short
# Sentence: The little boy pnted at the bird. | Predicted: panted | Correct: pointed
# Sentence: He found an old cmic in the attic. | Predicted: comic | Correct: comic
# Sentence: The bike tire was flt after the ride. | Predicted: felt | Correct: flat
# Sentence: She played the gutar for her friends. | Predicted: guitar | Correct: guitar
# Sentence: The bookcase was ful of old novels. | Predicted: full | Correct: full
# Sentence: He had a smth voice when he spoke. | Predicted: smith | Correct: smooth
# Sentence: She bought a nw phone yesterday. | Predicted: no | Correct: new
# Sentence: He took a bit of the sandwich. | Predicted: bit | Correct: bite
# Sentence: The cold air made my throt sore. | Predicted: throat | Correct: throat
# Sentence: They set up a tnt for camping. | Predicted: tent | Correct: tent
# Sentence: The dog dug in the grnd for its bone. | Predicted: grand | Correct: ground
# Sentence: She wore a bwl hat at the wedding. | Predicted: bowl | Correct: bowler
# Sentence: I saw a blu car in the driveway. | Predicted: blue | Correct: blue
# Sentence: He felt an emty space in his heart. | Predicted: empty | Correct: empty
# Sentence: She had a fver and felt sick. | Predicted: over | Correct: fever
# Sentence: They held a big feist at the end of the festival. | Predicted: fist | Correct: feast
# Sentence: The river flwed down the mountain. | Predicted: fled | Correct: flowed
# Sentence: She put the sppon on the table. | Predicted: spoon | Correct: spoon
# Sentence: The cat had soft fur and a lng tail. | Predicted: long | Correct: long
# Sentence: The brdge was made of stone. | Predicted: bridge | Correct: bridge
# Sentence: She bought a slk scarf from the market. | Predicted: silk | Correct: silk
# Sentence: His hnds were cold from the snow. | Predicted: hands | Correct: hands
# Sentence: The jcket was too tight to wear. | Predicted: jacket | Correct: jacket
# Sentence: We hiked up a stp hill. | Predicted: st | Correct: steep
# Sentence: The boy built a sndcastle by the shore. | Predicted: sndcastle | Correct: sandcastle
# Sentence: She read a paem to the class. | Predicted: palm | Correct: poem
# Sentence: The baker made fresh bred every morning. | Predicted: bred | Correct: bread
# Sentence: He drove down a strt road. | Predicted: sort | Correct: street
# Sentence: The plane was lw in the sky. | Predicted: law | Correct: low
# Sentence: She found a knd note on her desk. | Predicted: and | Correct: kind
# Sentence: The smke filled the room quickly. | Predicted: smoke | Correct: smoke
# Sentence: He left his clthes on the chair. | Predicted: clothes | Correct: clothes
# Sentence: The child splled juice on the floor. | Predicted: spilled | Correct: spilled
# Sentence: She wore a glden necklace to the party. | Predicted: golden | Correct: golden
# Sentence: The cnvas was stretched on the frame. | Predicted: canvas | Correct: canvas
# Sentence: His hert was beating fast. | Predicted: her | Correct: heart
# Sentence: She drank a glss of water. | Predicted: glass | Correct: glass
# Sentence: They heard a crck in the wall. | Predicted: crack | Correct: crack
# Sentence: The frst step is the hardest. | Predicted: first | Correct: first
# Sentence: He fnd a penny on the sidewalk. | Predicted: and | Correct: found
# Sentence: The brcks were red and rough. | Predicted: backs | Correct: bricks
# Sentence: She lost her hndbag at the mall. | Predicted: sandbag | Correct: handbag
# Sentence: The sun shne brightly in the sky. | Predicted: she | Correct: shone
# Sentence: They put the lmp on the table. | Predicted: lip | Correct: lamp
# Sentence: His wrk was admired by many. | Predicted: work | Correct: work
# Sentence: She took a brth before diving in. | Predicted: both | Correct: breath
# Sentence: The car had a dnt on the side. | Predicted: dint | Correct: dent
# Sentence: He held a cn of soda in his hand. | Predicted: in | Correct: can
# Sentence: She had a blck purse with her. | Predicted: back | Correct: black
# Sentence: The fld was covered in flowers. | Predicted: old | Correct: field
# Sentence: The girl had a lvely smile. | Predicted: lovely | Correct: lovely
# Sentence: They climbed the hil before sunset. | Predicted: his | Correct: hill
# Sentence: The chr was made of wood. | Predicted: cher | Correct: chair
# Sentence: She let out a sgh of relief. | Predicted: sigh | Correct: sigh
# Sentence: The frm was located in the valley. | Predicted: from | Correct: farm
# Sentence: His knck on the door was loud. | Predicted: knock | Correct: knock
# Sentence: She found a pge missing from the book. | Predicted: age | Correct: page
# Sentence: He had a prfession in law. | Predicted: profession | Correct: profession
# Sentence: The nmb feeling in his hand was strange. | Predicted: mb | Correct: numb
# Sentence: She gave a drct answer to the question. | Predicted: duct | Correct: direct
# Sentence: The cat scrtched the couch. | Predicted: scratched | Correct: scratched
# Sentence: He was given an opporunity to travel. | Predicted: opportunity | Correct: opportunity
# Sentence: She wrote her signture on the form. | Predicted: signature | Correct: signature
# Sentence: The fcture in the wall was repaired. | Predicted: future | Correct: fracture
#
# ----------- Overall Accuracy -----------
# 43/97 (44.33%)

# %% [markdown]
# # This solution did not work

# %% [markdown]
# This is based on the mentioned idea about calculating CBOW embeddings for predicting the most alike corrections. Since the number of context words varies significantly, we cannot just predict the embedding well, making it necessary to get the mean embedding of the context words. Probably it is possible to make it work this way with adding special tokens instead of missing words(for example when the misspelled word is located at the end of a sentence), but I did not get good results while trying to implement it, mainly because it takes a lot of time to train meaninful embeddings while making little changes. (less than 50 epochs is useless on this dataset, more than 50 epochs takes more than 3 hous to train)

# %%
import os
from gensim.models import Word2Vec
from gensim.utils import tokenize
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import re

def load_dataset(file_path="/kaggle/input/big-text/big.txt"):
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            text = f.read()
            sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|\!)\s', text)
            for sentence in sentences:
                yield list(tokenize(sentence.lower(), deacc=True))
    except UnicodeDecodeError:
        print(f"Error: Unable to read {file_path} as a text file.")

def initialize_model(sentences, embedding_size=300, window=5, min_count=20, workers=8):
    model = Word2Vec(
        vector_size=embedding_size,
        window=window,
        min_count=min_count,
        sg=0,
        workers=workers
    )
    model.build_vocab(sentences)
    return model

def train_model_incrementally(model, sentences, epochs=10):
    print(f"Training model...")
    total_examples = len(sentences)
    for epoch in range(epochs):
        print(f"Epoch {epoch + 1}/{epochs}")
        model.train(sentences, total_examples=total_examples, epochs=1)
    return model

def generate_candidates(word, edit_distance=2):
    letters = 'abcdefghijklmnopqrstuvwxyz'
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    operations = {
        'deletes': [L + R[1:] for L, R in splits if R],
        'inserts': [L + c + R for L, R in splits for c in letters],
        'replaces': [L + c + R[1:] for L, R in splits if R for c in letters]
    }
    candidates = set().union(*operations.values())
    if edit_distance == 2:
        candidates.update([c2 for c1 in candidates for c2 in generate_candidates(c1, 1)])
    return candidates

def correct_spelling(model, word, context_words, verbose=True):
    if verbose:
        print(f"Correcting spelling for: {word}")
        print(f"Context: {context_words}")

    candidates = generate_candidates(word)
    if verbose:
        print(f"{len(candidates)} candidates found")

    valid_candidates = [c for c in candidates if c in model.wv]
    if verbose:
        print(f"Valid corrections: {valid_candidates}")

    if not valid_candidates:
        if verbose:
            print("No valid candidates")
        return word

    context_embeddings = [model.wv[w] for w in context_words if w in model.wv]
    if not context_embeddings:
        if verbose:
            print("No valid context, something went wrong")
        return word
        
    context_vector = np.mean(context_embeddings, axis=0)

    output_weights = model.syn1neg

    candidate_indices = [model.wv.key_to_index[c] for c in valid_candidates]
    candidate_scores = np.dot(context_vector, output_weights[candidate_indices].T)
    
    best_idx = np.argmax(candidate_scores)
    best_candidate = valid_candidates[best_idx]
    
    if verbose:
        print(f"Predicted scores:")
        for c, score in zip(valid_candidates, candidate_scores):
            print(f"{c}: {score}")
        print(f"Best correction: '{best_candidate}'")

    return best_candidate

def load_eval_dataset(file_path="eval.txt"):
    data = []
    
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split('|')
            if len(parts) != 3:
                continue
            
            sentence, misspelled, correct = parts
            words = sentence.split()
            
            if misspelled in words:
                words.remove(misspelled)
            
            data.append({
                'sentence': sentence,
                'misspelled': misspelled,
                'correct': correct,
                'context': words
            })
    
    return data

def evaluate_model(model, eval_data):
    correct = 0
    total = 0
    
    for case in eval_data:
        predicted = correct_spelling(model, case['misspelled'], case['context'], verbose=False)
        print(f"Sentence: {case['sentence']} | Predicted: {predicted} | Correct: {case['correct']}")
        
        total += 1
        
        if predicted == case['correct']:
            correct += 1

    overall_accuracy = correct / total if total > 0 else 0
    
    print(f"\n{' Overall Accuracy '}")
    print(f"{correct}/{total} ({overall_accuracy})\n")

# %%
if __name__ == "__main__":
    print("Loading dataset...")
    sentences = list(load_dataset(file_path="/kaggle/input/smaller_train/train(1).txt"))
    print(f"Loaded {len(sentences)} sentences for training")

    model = initialize_model(sentences)

    epochs = 50
    model = train_model_incrementally(model, sentences, epochs=epochs)
    model.save("cbow_model_final.bin")
    print("Final model saved as cbow_model_final.bin")

    print("Loading eval dataset...")
    eval_data = load_eval_dataset("/kaggle/input/eval-ambiguous/eval.txt")
    print(f"Loaded {len(eval_data)} evaluation cases")
    print("Evaluating model...")
    evaluate_model(model, eval_data)
# Out:
# Loading dataset...
# Loaded 12013910 sentences for training
# Training model...
# Epoch 1/50
# Epoch 2/50
# Epoch 3/50
# Epoch 4/50
# Epoch 5/50
# Epoch 6/50
# Epoch 7/50
# Epoch 8/50
# Epoch 9/50
# Epoch 10/50
# Epoch 11/50
# Epoch 12/50
# Epoch 13/50
# Epoch 14/50
# Epoch 15/50
# Epoch 16/50
# Epoch 17/50
# Epoch 18/50
# Epoch 19/50
# Epoch 20/50
# Epoch 21/50
# Epoch 22/50
# Epoch 23/50
# Epoch 24/50
# Epoch 25/50
# Epoch 26/50
# Epoch 27/50
# Epoch 28/50
# Epoch 29/50
# Epoch 30/50
# Epoch 31/50
# Epoch 32/50
# Epoch 33/50
# Epoch 34/50
# Epoch 35/50
# Epoch 36/50
# Epoch 37/50
# Epoch 38/50
# Epoch 39/50
# Epoch 40/50
# Epoch 41/50
# Epoch 42/50
# Epoch 43/50
# Epoch 44/50
# Epoch 45/50
# Epoch 46/50
# Epoch 47/50
# Epoch 48/50
# Epoch 49/50
# Epoch 50/50
# Saving final model...
# Final model saved as cbow_model_final.bin
# Loading evaluation dataset...
# Loaded 97 evaluation cases
# Evaluating model...
# Sentence: The car drve fast on the highway. | Predicted: driver | Correct: drove
# Sentence: She saw a brid flying in the sky. | Predicted: bird | Correct: bird
# Sentence: He used a pencl to write notes. | Predicted: pen | Correct: pencil
# Sentence: They found a brwn puppy in the park. | Predicted: fawn | Correct: brown
# Sentence: My friend brke his phone screen. | Predicted: broker | Correct: broke
# Sentence: The dog dug a hol in the yard. | Predicted: hole | Correct: hole
# Sentence: She wore a yelow dress to the party. | Predicted: yellow | Correct: yellow
# Sentence: I heard a lod noise outside. | Predicted: loud | Correct: loud
# Sentence: The old man had a wlk in the garden. | Predicted: hulk | Correct: walk
# Sentence: We took a bote to the island. | Predicted: route | Correct: boat
# Sentence: His glss broke when it fell. | Predicted: gits | Correct: glass
# Sentence: She drew a smal picture in her notebook. | Predicted: shawl | Correct: small
# Sentence: The fire brnt the wood completely. | Predicted: burn | Correct: burnt
# Sentence: The child liks to play in the park. | Predicted: jigs | Correct: likes
# Sentence: She had a hrd time solving the puzzle. | Predicted: third | Correct: hard
# Sentence: The storm clsed all the roads. | Predicted: cloud | Correct: closed
# Sentence: We saw a bwl of fruit on the table. | Predicted: bulb | Correct: bowl
# Sentence: She put a buk on the shelf. | Predicted: rug | Correct: book
# Sentence: The cat jumpd onto the windowsill. | Predicted: jumps | Correct: jumped
# Sentence: He set the clock to wke him early. | Predicted: wu | Correct: wake
# Sentence: They sent a lter to their cousin. | Predicted: voter | Correct: letter
# Sentence: I ate a bow of soup for lunch. | Predicted: bowl | Correct: bowl
# Sentence: He left his cke on the table. | Predicted: eye | Correct: cake
# Sentence: She saw a bech covered in seashells. | Predicted: bush | Correct: beach
# Sentence: The child clmbed the tree. | Predicted: combe | Correct: climbed
# Sentence: He spent his evning watching TV. | Predicted: evenings | Correct: evening
# Sentence: She made a brad sandwich. | Predicted: raid | Correct: bread
# Sentence: The baby crwed across the floor. | Predicted: creek | Correct: crawled
# Sentence: The kite flw high in the sky. | Predicted: flew | Correct: flew
# Sentence: They saw a bule fish in the lake. | Predicted: hole | Correct: blue
# Sentence: His wrst was hurting after the fall. | Predicted: wrist | Correct: wrist
# Sentence: The teacher gave a qiz today. | Predicted: tip | Correct: quiz
# Sentence: She wore a shrt jacket in the cold. | Predicted: shirt | Correct: short
# Sentence: The little boy pnted at the bird. | Predicted: petted | Correct: pointed
# Sentence: He found an old cmic in the attic. | Predicted: crick | Correct: comic
# Sentence: The bike tire was flt after the ride. | Predicted: alto | Correct: flat
# Sentence: She played the gutar for her friends. | Predicted: guitar | Correct: guitar
# Sentence: The bookcase was ful of old novels. | Predicted: dut | Correct: full
# Sentence: He had a smth voice when he spoke. | Predicted: sigh | Correct: smooth
# Sentence: She bought a nw phone yesterday. | Predicted: cow | Correct: new
# Sentence: He took a bit of the sandwich. | Predicted: lot | Correct: bite
# Sentence: The cold air made my throt sore. | Predicted: hot | Correct: throat
# Sentence: They set up a tnt for camping. | Predicted: het | Correct: tent
# Sentence: The dog dug in the grnd for its bone. | Predicted: ground | Correct: ground
# Sentence: She wore a bwl hat at the wedding. | Predicted: belt | Correct: bowler
# Sentence: I saw a blu car in the driveway. | Predicted: bus | Correct: blue
# Sentence: He felt an emty space in his heart. | Predicted: empty | Correct: empty
# Sentence: She had a fver and felt sick. | Predicted: fever | Correct: fever
# Sentence: They held a big feist at the end of the festival. | Predicted: feast | Correct: feast
# Sentence: The river flwed down the mountain. | Predicted: flowed | Correct: flowed
# Sentence: She put the sppon on the table. | Predicted: spot | Correct: spoon
# Sentence: The cat had soft fur and a lng tail. | Predicted: rug | Correct: long
# Sentence: The brdge was made of stone. | Predicted: brags | Correct: bridge
# Sentence: She bought a slk scarf from the market. | Predicted: silk | Correct: silk
# Sentence: His hnds were cold from the snow. | Predicted: winds | Correct: hands
# Sentence: The jcket was too tight to wear. | Predicted: jacket | Correct: jacket
# Sentence: We hiked up a stp hill. | Predicted: mop | Correct: steep
# Sentence: The boy built a sndcastle by the shore. | Predicted: oldcastle | Correct: sandcastle
# Sentence: She read a paem to the class. | Predicted: poem | Correct: poem
# Sentence: The baker made fresh bred every morning. | Predicted: bread | Correct: bread
# Sentence: He drove down a strt road. | Predicted: sat | Correct: street
# Sentence: The plane was lw in the sky. | Predicted: tv | Correct: low
# Sentence: She found a knd note on her desk. | Predicted: pad | Correct: kind
# Sentence: The smke filled the room quickly. | Predicted: smoky | Correct: smoke
# Sentence: He left his clthes on the chair. | Predicted: clothes | Correct: clothes
# Sentence: The child splled juice on the floor. | Predicted: spilled | Correct: spilled
# Sentence: She wore a glden necklace to the party. | Predicted: golden | Correct: golden
# Sentence: The cnvas was stretched on the frame. | Predicted: canvas | Correct: canvas
# Sentence: His hert was beating fast. | Predicted: heart | Correct: heart
# Sentence: She drank a glss of water. | Predicted: glass | Correct: glass
# Sentence: They heard a crck in the wall. | Predicted: cry | Correct: crack
# Sentence: The frst step is the hardest. | Predicted: first | Correct: first
# Sentence: He fnd a penny on the sidewalk. | Predicted: lend | Correct: found
# Sentence: The brcks were red and rough. | Predicted: locks | Correct: bricks
# Sentence: She lost her hndbag at the mall. | Predicted: handbag | Correct: handbag
# Sentence: The sun shne brightly in the sky. | Predicted: shines | Correct: shone
# Sentence: They put the lmp on the table. | Predicted: lid | Correct: lamp
# Sentence: His wrk was admired by many. | Predicted: way | Correct: work
# Sentence: She took a brth before diving in. | Predicted: bath | Correct: breath
# Sentence: The car had a dnt on the side. | Predicted: jet | Correct: dent
# Sentence: He held a cn of soda in his hand. | Predicted: cup | Correct: can
# Sentence: She had a blck purse with her. | Predicted: hack | Correct: black
# Sentence: The fld was covered in flowers. | Predicted: mud | Correct: field
# Sentence: The girl had a lvely smile. | Predicted: lovely | Correct: lovely
# Sentence: They climbed the hil before sunset. | Predicted: rim | Correct: hill
# Sentence: The chr was made of wood. | Predicted: who | Correct: chair
# Sentence: She let out a sgh of relief. | Predicted: sight | Correct: sigh
# Sentence: The frm was located in the valley. | Predicted: ore | Correct: farm
# Sentence: His knck on the door was loud. | Predicted: lock | Correct: knock
# Sentence: She found a pge missing from the book. | Predicted: ore | Correct: page
# Sentence: He had a prfession in law. | Predicted: procession | Correct: profession
# Sentence: The nmb feeling in his hand was strange. | Predicted: numb | Correct: numb
# Sentence: She gave a drct answer to the question. | Predicted: direct | Correct: direct
# Sentence: The cat scrtched the couch. | Predicted: scratched | Correct: scratched
# Sentence: He was given an opporunity to travel. | Predicted: opportunity | Correct: opportunity
# Sentence: She wrote her signture on the form. | Predicted: signature | Correct: signature
# Sentence: The fcture in the wall was repaired. | Predicted: picture | Correct: fracture
#
# ----------- Overall Accuracy -----------
# 31/97 (31.96%)

# %%
print("Sanity check - Most similar to king:")
print(model.wv.most_similar("king", topn=5))

print("Sanity check - Most similar to bread:")
print(model.wv.most_similar("bread", topn=5))

# %% [markdown]
# # Solution that worked well

# %% [markdown]
# This solution works in a similar matter to CBOW. The difference is that the pre-trained BERT model is used to predict the masked misspelled word and compare the embeddings with candidate corrections. It still works quite fast, keeping the correction system efficient enough to use.

# %% [markdown]
# It works much better since it actually understand which words are better fit based on sentence context.

# %%
import re
import torch
import string
from collections import Counter
from transformers import BertTokenizer, BertForMaskedLM

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertForMaskedLM.from_pretrained("bert-base-uncased")
model.eval()

def words(text):
    return re.findall(r'\w+', text.lower())

def load_corpus(file_path='/kaggle/input/plain-text-wikipedia-simpleenglish/AllCombined.txt'):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

def word_probabilities(word_counts):
    total_words = sum(word_counts.values())
    return {word: count / total_words for word, count in word_counts.items()}


# Candidate generation function was brazenly stolen from Norvig's implementation
def edits1(word):
    letters = string.ascii_lowercase
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [L + R[1:] for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
    replaces = [L + c + R[1:] for L, R in splits if R for c in letters]
    inserts = [L + c + R for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word):
    return {e2 for e1 in edits1(word) for e2 in edits1(e1)}

def known(words, word_counts):
    return {word for word in words if word in word_counts}

def mask_and_predict(sentence, target_index):
    words = sentence.split()
    words[target_index] = "[MASK]"
    masked_sentence = " ".join(words)

    tokens = tokenizer(masked_sentence, return_tensors="pt")
    mask_index = tokens.input_ids[0].tolist().index(tokenizer.mask_token_id)

    with torch.no_grad():
        outputs = model(**tokens)
    predictions = outputs.logits[0, mask_index]

    top_tokens = torch.topk(predictions, 10).indices.tolist()
    predicted_words = [tokenizer.decode([token]).strip() for token in top_tokens]

    return predicted_words

def correct_spelling(sentence, target_index, word_counts):
    bert_predictions = mask_and_predict(sentence, target_index)
    
    print("\nTop BERT Predictions:")
    for i, word in enumerate(bert_predictions):
        print(f"{i + 1}. {word}")

    misspelled_word = sentence.split()[target_index]

    candidates = known(edits1(misspelled_word), word_counts) or \
                 known(edits2(misspelled_word), word_counts) or \
                 {misspelled_word}

    print(f"\nCandidate Words: {candidates}")

    for word in bert_predictions:
        if word in candidates:
            return word

    return max(candidates, key=word_counts.get, default=misspelled_word)

if __name__ == '__main__':
    corpus = load_corpus('/kaggle/input/plain-text-wikipedia-simpleenglish/AllCombined.txt')
    word_counts = Counter(words(corpus))
    word_probs = word_probabilities(word_counts)

    sentence = "I want to by a new laptop."
    target_index = 3

    corrected_word = correct_spelling(sentence, target_index, word_counts)
    print(f"Final Corrected Word: {corrected_word}")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Top BERT Predictions:
# 1. buy
# 2. get
# 3. have
# 4. build
# 5. purchase
# 6. open
# 7. find
# 8. start
# 9. make
# 10. order
#
# Candidate Words: {'bn', 'nby', 'boy', 'sy', 'bay', 'bc', 'bly', 'jy', 'pby', 'be', 'byn', 'my', 'ay', 'eby', 'py', 'bya', 'yy', 'bo', 'bm', 'bw', 'xy', 'bby', 'bj', 'oy', 'bv', 'bl', 'ty', 'byk', 'dy', 'bi', 'bp', 'bk', 'bq', 'uy', 'cy', 'byl', 'yb', 'bye', 'ey', 'wy', 'byu', 'ly', 'fy', 'byp', 'ky', 'aby', 'hy', 'bt', 'ry', 'bf', 'by', 'bu', 'byg', 'bd', 'br', 'bb', 'bx', 'zy', 'ny', 'y', 'byo', 'ba', 'byb', 'bz', 'bs', 'b', 'bh', 'bey', 'iy', 'bys', 'bg', 'bry', 'vy', 'gy', 'buy'}
#
# Final Corrected Word: buy

# %% [markdown]
# ## Justify your decisions
#
# Write down justificaitons for your implementation choices. For example, these choices could be:
# - Which ngram dataset to use
# - Which weights to assign for edit1, edit2 or absent words probabilities
# - Beam search parameters
# - etc.

# %% [markdown]
# As for datasets I used concatenated wikipedia snapshot + reddit dialogues for CBOW model and just wikipedia-small for vocabulary of BERT-based implementation. It is actually not too bad to use datasets aside from official vocabularies or other verified resources since the model ususally does not assign high probabilities to the words misspelled by users by mistake.

# %% [markdown]
# Because we are looking for corrections in the context-aware space, it does not matter much how much weight to assign to edit1 and edit2, since situations when we have two value-similar words which are 1 letter distant from each other are super rare and it is not required to pay a lot of attention to such cases.

# %% [markdown]
# The top-10 BERT candidates approach was chosen solely imperically to give better results and still keep the system stable and avoid ilogical word sequences.

# %% [markdown]
# ## Evaluate on a test set
#
# Your task is to generate a test set and evaluate your work. You may vary the noise probability to generate different datasets with varying compexity (or just take another dataset). Compare your solution to the Norvig's corrector, and report the accuracies.

# %% [markdown]
# Evaluation dataset was generated by an LLM just because those small datasets that I could find on the internet lacked ambiguity in terms of possible word meanings, which is a key parameter when testing a spelling corrector. It contains 97 different sentences with multiple word meanings.

# %% [markdown]
# The correction speed for BERT model is about 100 times slower compared to Norvig's solution, but still not too bad and is limited by approximately 0.1 seconds making it possible to use for usual purposes. Norvig's solution is simple string operations and takes about 0.001 per word. To make the system faster, we could use DistillBert or some similar model

# %%
def load_eval_dataset(file_path="eval.txt"):
    data = []
    
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.strip().split('|')
            if len(parts) != 3:
                continue
            
            sentence, misspelled, correct = parts
            words = sentence.split()
            
            if misspelled in words:
                words.remove(misspelled)
            
            data.append({
                'sentence': sentence,
                'misspelled': misspelled,
                'correct': correct,
                'context': words
            })
    
    return data

def evaluate_bert_model(eval_data, word_counts):
    correct_total = 0
    total = 0

    for case in eval_data:
        sentence = case['sentence']
        correct_word = case['correct']
        
        words = sentence.split()
        try:
            target_index = words.index(case['misspelled'])
        except ValueError:
            print(f"Skipping: {sentence} (Misspelled word not found)")
            continue

        predicted = correct_spelling(sentence, target_index, word_counts)

        print(f"Sentence: {sentence} | Predicted: {predicted} | Correct: {correct_word}")

        total += 1
        if predicted == correct_word:
            correct_total += 1

    overall_accuracy = correct_total / total if total > 0 else 0
    print(f"\n{' Overall Accuracy ':-^40}")
    print(f"{correct_total}/{total} ({overall_accuracy:.2%})\n")

if __name__ == '__main__':
    eval_data = load_eval_dataset('/kaggle/input/eval-ambiguous/eval.txt')
    evaluate_bert_model(eval_data, word_counts)
# Out:
# Top BERT Predictions:
# 1. was
# 2. moved
# 3. drove
# 4. went
# 5. turned
# 6. ran
# 7. stopped
# 8. spun
# 9. sped
# 10. got
#
# Candidate Words: {'erve', 'drv', 'dive', 'drse', 'drue', 'drave', 'orve', 'drive', 'irve', 'arve', 'drev', 'drove', 'dre', 'dave', 'duve', 'dove', 'deve', 'dree', 'dve'}
# Sentence: The car drve fast on the highway. | Predicted: drove | Correct: drove
#
# Top BERT Predictions:
# 1. helicopter
# 2. bird
# 3. plane
# 4. figure
# 5. shadow
# 6. ufo
# 7. ship
# 8. comet
# 9. shape
# 10. cloud
#
# Candidate Words: {'brd', 'brid', 'barid', 'arid', 'frid', 'drid', 'brio', 'rid', 'brie', 'bri', 'briz', 'bred', 'brind', 'bric', 'grid', 'krid', 'brik', 'braid', 'brix', 'bris', 'brit', 'brij', 'bid', 'brih', 'bird', 'bria', 'bridi', 'brim', 'brin', 'briw', 'brig', 'bride', 'bruid', 'brod', 'urid', 'brad'}
# Sentence: She saw a brid flying in the sky. | Predicted: bird | Correct: bird
#
# Top BERT Predictions:
# 1. pen
# 2. pencil
# 3. notebook
# 4. cane
# 5. comb
# 6. computer
# 7. machine
# 8. stick
# 9. book
# 10. brush
#
# Candidate Words: {'pence', 'pencil', 'penal', 'pecl', 'pendl', 'pench', 'opencl', 'penca', 'penco', 'penck'}
# Sentence: He used a pencl to write notes. | Predicted: pencil | Correct: pencil
#
# Top BERT Predictions:
# 1. dead
# 2. stray
# 3. lost
# 4. new
# 5. missing
# 6. little
# 7. small
# 8. cute
# 9. young
# 10. stuffed
#
# Candidate Words: {'brn', 'bren', 'bran', 'brin', 'bron', 'bwn', 'brw', 'brun', 'brawn', 'brtn', 'bawn', 'bryn', 'brown', 'bown'}
# Sentence: They found a brwn puppy in the park. | Predicted: brown | Correct: brown
#
# Top BERT Predictions:
# 1. checked
# 2. checks
# 3. tapped
# 4. taps
# 5. touched
# 6. scans
# 7. studied
# 8. check
# 9. touches
# 10. watches
#
# Candidate Words: {'bree', 'brue', 'bake', 'arke', 'brae', 'bruke', 'brk', 'brie', 'brake', 'burke', 'berke', 'boke', 'beke', 'bike', 'broke', 'bre', 'birke'}
# Sentence: My friend brke his phone screen. | Predicted: broke | Correct: broke
#
# Top BERT Predictions:
# 1. hole
# 2. grave
# 3. trench
# 4. well
# 5. pit
# 6. ditch
# 7. path
# 8. circle
# 9. tunnel
# 10. trail
#
# Candidate Words: {'holo', 'ool', 'uol', 'hou', 'ol', 'hocl', 'hod', 'tol', 'hoi', 'fol', 'holc', 'how', 'hql', 'dol', 'mhol', 'holt', 'hfl', 'chol', 'hor', 'hvl', 'ohl', 'hnl', 'hoo', 'jol', 'hox', 'col', 'yol', 'hal', 'hll', 'hohl', 'lol', 'howl', 'mol', 'rol', 'hsl', 'holl', 'holy', 'hob', 'hoc', 'nol', 'hot', 'bol', 'hole', 'kol', 'hols', 'khol', 'hok', 'htl', 'jhol', 'vol', 'wol', 'hold', 'hol', 'hcl', 'dhol', 'hov', 'hoz', 'thol', 'eol', 'ho', 'hil', 'hl', 'phol', 'hel', 'pol', 'hoe', 'hool', 'hos', 'hom', 'hola', 'hoy', 'hop', 'hon', 'hoh', 'aol', 'hof', 'gol', 'hog', 'sol', 'holz', 'holi', 'holm', 'hkl', 'hoa', 'hdl'}
# Sentence: The dog dug a hol in the yard. | Predicted: hole | Correct: hole
#
# Top BERT Predictions:
# 1. black
# 2. white
# 3. red
# 4. pink
# 5. green
# 6. blue
# 7. cocktail
# 8. purple
# 9. long
# 10. wedding
#
# Candidate Words: {'yeow', 'yelo', 'yalow', 'below', 'yellow'}
# Sentence: She wore a yelow dress to the party. | Predicted: below | Correct: yellow
#
# Top BERT Predictions:
# 1. loud
# 2. strange
# 3. crashing
# 4. muffled
# 5. small
# 6. scraping
# 7. faint
# 8. rustling
# 9. slight
# 10. shuffling
#
# Candidate Words: {'led', 'nod', 'log', 'lud', 'loud', 'lok', 'old', 'lod', 'od', 'vod', 'flod', 'hod', 'lom', 'lid', 'god', 'yod', 'lpd', 'lyd', 'mod', 'lon', 'loda', 'lop', 'iod', 'bod', 'elod', 'load', 'lodi', 'lov', 'eod', 'lord', 'lood', 'lof', 'cod', 'blod', 'lob', 'lond', 'ood', 'loh', 'zod', 'plod', 'lld', 'rod', 'lo', 'lbd', 'lor', 'lol', 'lrod', 'loz', 'jod', 'loyd', 'tod', 'loc', 'wod', 'glod', 'lou', 'loo', 'loy', 'lodz', 'dod', 'sod', 'lot', 'lmd', 'loi', 'low', 'loa', 'lad', 'fod', 'kod', 'lods', 'pod', 'lsd', 'ltd', 'clod', 'loe', 'lode', 'lcd', 'lhd', 'ld', 'los', 'lox', 'aod'}
# Sentence: I heard a lod noise outside. | Predicted: loud | Correct: loud
#
# Top BERT Predictions:
# 1. house
# 2. garden
# 3. place
# 4. room
# 5. home
# 6. cottage
# 7. grave
# 8. dog
# 9. horse
# 10. cat
#
# Candidate Words: {'welk', 'slk', 'clk', 'wsk', 'glk', 'wll', 'wilk', 'wk', 'klk', 'wlkp', 'wuk', 'wls', 'wok', 'elk', 'walk', 'wik', 'ilk', 'wyk', 'ulk', 'wlg', 'wl', 'vlk', 'wwk', 'mlk', 'alk', 'wla', 'lk', 'plk', 'wpk', 'wln', 'wak', 'wlo', 'wlt', 'flk', 'olk', 'wek', 'wlw', 'blk'}
# Sentence: The old man had a wlk in the garden. | Predicted: walk | Correct: walk
#
# Top BERT Predictions:
# 1. cab
# 2. taxi
# 3. walk
# 4. boat
# 5. trip
# 6. ride
# 7. ferry
# 8. path
# 9. flight
# 10. train
#
# Candidate Words: {'bone', 'both', 'hote', 'kote', 'bott', 'boxe', 'bole', 'mote', 'botel', 'bothe', 'bots', 'botez', 'botte', 'wote', 'botz', 'bope', 'botet', 'bte', 'bose', 'rote', 'bota', 'zote', 'boet', 'bute', 'tote', 'bate', 'boty', 'boten', 'bove', 'boie', 'boate', 'obote', 'bote', 'bhote', 'bete', 'bode', 'bowe', 'vote', 'note', 'boke', 'botes', 'bore', 'pote', 'botn', 'bmte', 'boto', 'botev', 'bite', 'byte', 'boye', 'boe', 'gote', 'cote', 'bot', 'bolte'}
# Sentence: We took a bote to the island. | Predicted: both | Correct: boat
#
# Top BERT Predictions:
# 1. voice
# 2. heart
# 3. jaw
# 4. face
# 5. glass
# 6. head
# 7. hand
# 8. arm
# 9. nose
# 10. gaze
#
# Candidate Words: {'gcss', 'gnss', 'gtss', 'glos', 'glis', 'gless', 'gass', 'gliss', 'glsl', 'gloss', 'guss', 'gpss', 'glass', 'glas', 'gss', 'rlss', 'goss', 'gls', 'ghss'}
# Sentence: His glss broke when it fell. | Predicted: glass | Correct: glass
#
# Top BERT Predictions:
# 1. small
# 2. large
# 3. big
# 4. little
# 5. mental
# 6. tiny
# 7. new
# 8. quick
# 9. different
# 10. simple
#
# Candidate Words: {'seal', 'cmal', 'shal', 'smyl', 'omal', 'smal', 'sman', 'smail', 'sial', 'smak', 'sma', 'smeal', 'smas', 'smap', 'sal', 'smalt', 'smaal', 'amal', 'smale', 'smial', 'small', 'skal', 'syal', 'samal', 'smil', 'saal', 'stal', 'mal', 'smaw', 'spal', 'smad'}
# Sentence: She drew a smal picture in her notebook. | Predicted: small | Correct: small
#
# Top BERT Predictions:
# 1. consumed
# 2. engulfed
# 3. burned
# 4. covered
# 5. destroyed
# 6. extinguished
# 7. warmed
# 8. swallowed
# 9. melted
# 10. filled
#
# Candidate Words: {'brut', 'brunt', 'bunt', 'brat', 'brn', 'bront', 'barnt', 'brint', 'bent', 'bryt', 'burnt', 'brit', 'brno', 'bret', 'bint', 'brent', 'brant', 'bernt', 'bont', 'brtn', 'brot', 'brt'}
# Sentence: The fire brnt the wood completely. | Predicted: burnt | Correct: burnt
#
# Top BERT Predictions:
# 1. wanted
# 2. goes
# 3. used
# 4. continued
# 5. wants
# 6. continues
# 7. went
# 8. had
# 9. has
# 10. likes
#
# Candidate Words: {'likes', 'fliks', 'lies', 'luks', 'laks', 'diks', 'links', 'iks', 'licks', 'lips', 'leks', 'lids', 'lik', 'uliks', 'lins', 'like', 'likas', 'lias', 'liss', 'riks', 'lios', 'lika', 'lis', 'libs', 'loks', 'liko', 'lks', 'niks'}
# Sentence: The child liks to play in the park. | Predicted: likes | Correct: likes
#
# Top BERT Predictions:
# 1. hard
# 2. difficult
# 3. tough
# 4. harder
# 5. rough
# 6. great
# 7. terrible
# 8. good
# 9. wonderful
# 10. tricky
#
# Candidate Words: {'urd', 'brd', 'frd', 'rd', 'erd', 'hard', 'hud', 'hurd', 'had', 'hwd', 'wrd', 'hrad', 'hrt', 'hr', 'jrd', 'hrk', 'hrs', 'hod', 'xrd', 'hrh', 'hird', 'hrw', 'hmd', 'hrd', 'ord', 'hry', 'herd', 'hdd', 'hrm', 'ird', 'hrg', 'hid', 'ard', 'hpd', 'hdr', 'hnd', 'hrc', 'hrp', 'hcd', 'rhd', 'hra', 'hhd', 'hrds', 'hed', 'prd', 'hd'}
# Sentence: She had a hrd time solving the puzzle. | Predicted: hard | Correct: hard
#
# Top BERT Predictions:
# 1. destroyed
# 2. blocked
# 3. damaged
# 4. flooded
# 5. wrecked
# 6. closed
# 7. affected
# 8. burned
# 9. ruined
# 10. devastated
#
# Candidate Words: {'closed', 'cased', 'clued'}
# Sentence: The storm clsed all the roads. | Predicted: closed | Correct: closed
#
# Top BERT Predictions:
# 1. bowl
# 2. plate
# 3. basket
# 4. piece
# 5. bunch
# 6. tray
# 7. box
# 8. bag
# 9. selection
# 10. can
#
# Candidate Words: {'iwl', 'bwa', 'bawl', 'gwl', 'bnl', 'bwt', 'bil', 'bkl', 'blw', 'owl', 'bowl', 'bwv', 'bw', 'bsl', 'bl', 'bwm', 'pwl', 'bdl', 'bal', 'byl', 'bol', 'bul', 'ewl', 'bwo', 'bwi', 'wl', 'bwf', 'bwn', 'awl', 'wbl', 'bcl', 'bel', 'bwh', 'lwl', 'bbl', 'bpl', 'bwbl', 'wwl', 'bwk'}
# Sentence: We saw a bwl of fruit on the table. | Predicted: bowl | Correct: bowl
#
# Top BERT Predictions:
# 1. book
# 2. box
# 3. bottle
# 4. bag
# 5. card
# 6. pen
# 7. glass
# 8. candle
# 9. key
# 10. picture
#
# Candidate Words: {'ubk', 'bok', 'kuk', 'buf', 'buka', 'bub', 'buek', 'bux', 'bmk', 'bulk', 'muk', 'wuk', 'buh', 'bum', 'bak', 'but', 'byk', 'buc', 'bgk', 'bsk', 'buk', 'buj', 'bus', 'rbuk', 'ruk', 'buck', 'bue', 'blk', 'bk', 'burk', 'tuk', 'buu', 'buko', 'bul', 'cuk', 'fuk', 'bur', 'btk', 'bek', 'beuk', 'uk', 'bkk', 'bunk', 'bun', 'brk', 'bruk', 'luk', 'suk', 'buky', 'bua', 'bug', 'bu', 'puk', 'busk', 'guk', 'bui', 'bjk', 'vuk', 'bbk', 'yuk', 'ouk', 'auk', 'nuk', 'duk', 'bud', 'buy', 'bwk'}
# Sentence: She put a buk on the shelf. | Predicted: but | Correct: book
#
# Top BERT Predictions:
# 1. jumped
# 2. hopped
# 3. leaped
# 4. climbed
# 5. leapt
# 6. crawled
# 7. dropped
# 8. flopped
# 9. fell
# 10. thumped
#
# Candidate Words: {'jumpy', 'jump', 'jumps', 'jumped'}
# Sentence: The cat jumpd onto the windowsill. | Predicted: jumped | Correct: jumped
#
# Top BERT Predictions:
# 1. wake
# 2. greet
# 3. catch
# 4. call
# 5. remind
# 6. meet
# 7. alert
# 8. put
# 9. tell
# 10. keep
#
# Candidate Words: {'wee', 'wake', 'wka', 'kwe', 'woke', 'wkf', 'wk', 'eke', 'ke', 'wre', 'wkn', 'ike', 'wike', 'wme', 'wne', 'wse', 'wke', 'gke', 'ske', 'cke', 'we', 'wie', 'wks', 'woe', 'uke', 'wae', 'wye', 'oke', 'wyke', 'wek', 'kke', 'wwe'}
# Sentence: He set the clock to wke him early. | Predicted: wake | Correct: wake
#
# Top BERT Predictions:
# 1. message
# 2. letter
# 3. messenger
# 4. note
# 5. call
# 6. telegram
# 7. text
# 8. signal
# 9. report
# 10. reply
#
# Candidate Words: {'liter', 'later', 'lte', 'ster', 'lner', 'ater', 'lker', 'iter', 'lier', 'fter', 'leer', 'ter', 'lter', 'alter', 'ler', 'luter'}
# Sentence: They sent a lter to their cousin. | Predicted: later | Correct: letter
#
# Top BERT Predictions:
# 1. bowl
# 2. lot
# 3. can
# 4. pot
# 5. cup
# 6. bit
# 7. plate
# 8. bite
# 9. piece
# 10. bottle
#
# Candidate Words: {'bom', 'bok', 'btw', 'bmw', 'boy', 'bowa', 'brow', 'now', 'yow', 'bof', 'jow', 'bkw', 'vow', 'bew', 'gow', 'blw', 'bo', 'bowl', 'bw', 'bou', 'iow', 'tow', 'sow', 'row', 'boh', 'boi', 'pow', 'box', 'mow', 'bgw', 'bouw', 'boz', 'bpow', 'bol', 'uow', 'bwo', 'bos', 'bop', 'bor', 'bog', 'blow', 'baw', 'brw', 'boj', 'bowe', 'bob', 'boo', 'boa', 'bows', 'bcw', 'how', 'bon', 'bod', 'ow', 'boc', 'kow', 'wow', 'boe', 'cow', 'bow', 'dow', 'low', 'bot', 'bown'}
# Sentence: I ate a bow of soup for lunch. | Predicted: bowl | Correct: bowl
#
# Top BERT Predictions:
# 1. cup
# 2. cards
# 3. phone
# 4. keys
# 5. glass
# 6. napkin
# 7. coffee
# 8. hand
# 9. glasses
# 10. purse
#
# Candidate Words: {'cge', 'cae', 'cve', 'ckd', 'cake', 'cpe', 'cky', 'che', 'cue', 'ckge', 'eke', 'cre', 'coe', 'cki', 'ke', 'cte', 'cek', 'cfe', 'cze', 'kce', 'ckc', 'cce', 'ike', 'icke', 'cie', 'ce', 'wke', 'cme', 'ck', 'gke', 'cbe', 'ske', 'cse', 'cke', 'uke', 'ckem', 'cee', 'cne', 'oke', 'coke', 'cle', 'kke', 'cde', 'cked', 'cka'}
# Sentence: He left his cke on the table. | Predicted: ce | Correct: cake
#
# Top BERT Predictions:
# 1. table
# 2. chest
# 3. shelf
# 4. wall
# 5. box
# 6. vase
# 7. bed
# 8. cabinet
# 9. basket
# 10. door
#
# Candidate Words: {'besch', 'beeh', 'bsch', 'sech', 'yech', 'rech', 'boch', 'beth', 'beah', 'besh', 'bench', 'beach', 'jech', 'kech', 'lech', 'buch', 'bach', 'mech', 'ech', 'belch', 'beh', 'beech', 'bch', 'fech', 'wech', 'beck', 'blech', 'pech', 'begh', 'bich', 'zech', 'beche', 'cech', 'bech', 'tech', 'bec'}
# Sentence: She saw a bech covered in seashells. | Predicted: beach | Correct: beach
#
# Top BERT Predictions:
# 1. in
# 2. of
# 3. from
# 4. and
# 5. ,
# 6. inside
# 7. under
# 8. .
# 9. on
# 10. at
#
# Candidate Words: {'combed', 'climbed'}
# Sentence: The child clmbed the tree. | Predicted: climbed | Correct: climbed
#
# Top BERT Predictions:
# 1. time
# 2. days
# 3. nights
# 4. evenings
# 5. day
# 6. afternoons
# 7. hours
# 8. weekends
# 9. mornings
# 10. life
#
# Candidate Words: {'eining', 'evening'}
# Sentence: He spent his evning watching TV. | Predicted: evening | Correct: evening
#
# Top BERT Predictions:
# 1. turkey
# 2. ham
# 3. quick
# 4. chicken
# 5. small
# 6. cheese
# 7. good
# 8. bacon
# 9. new
# 10. short
#
# Candidate Words: {'brd', 'brac', 'brid', 'brat', 'bral', 'brod', 'brads', 'braz', 'arad', 'bard', 'erad', 'bhad', 'hrad', 'frad', 'bred', 'bra', 'brag', 'baad', 'broad', 'bread', 'brak', 'rad', 'braid', 'barad', 'brar', 'brau', 'bray', 'brax', 'bras', 'urad', 'brda', 'brado', 'brand', 'bad', 'bran', 'brae', 'brad', 'irad', 'bradu', 'bram', 'prad', 'brady', 'grad', 'trad', 'bead', 'braud', 'bradt', 'braj'}
# Sentence: She made a brad sandwich. | Predicted: bad | Correct: bread
#
# Top BERT Predictions:
# 1. rolled
# 2. slid
# 3. fell
# 4. tumbled
# 5. sprawled
# 6. bounced
# 7. flew
# 8. crawled
# 9. spilled
# 10. lay
#
# Candidate Words: {'cowed', 'crowed', 'cried', 'creed', 'crewed'}
# Sentence: The baby crwed across the floor. | Predicted: creed | Correct: crawled
#
# Top BERT Predictions:
# 1. was
# 2. flew
# 3. hung
# 4. soared
# 5. is
# 6. flies
# 7. floated
# 8. hangs
# 9. sailed
# 10. hovered
#
# Candidate Words: {'fgw', 'vflw', 'flo', 'flv', 'blw', 'fla', 'fln', 'flow', 'flrw', 'plw', 'flt', 'fls', 'fll', 'fly', 'flq', 'fmw', 'flaw', 'fl', 'flu', 'alw', 'fw', 'lw', 'flew', 'mlw', 'vlw', 'fcw', 'flm', 'ftw', 'aflw', 'few', 'fld', 'faw', 'flk', 'flc', 'wlw', 'fli'}
# Sentence: The kite flw high in the sky. | Predicted: flew | Correct: flew
#
# Top BERT Predictions:
# 1. few
# 2. large
# 3. big
# 4. small
# 5. little
# 6. dead
# 7. huge
# 8. white
# 9. live
# 10. giant
#
# Candidate Words: {'lule', 'nule', 'bull', 'tule', 'bole', 'sule', 'brule', 'ule', 'baule', 'bure', 'blue', 'bugle', 'bulk', 'mule', 'buble', 'boule', 'yule', 'ble', 'rule', 'buale', 'bulle', 'bulge', 'bula', 'bue', 'buhe', 'bulb', 'bale', 'bute', 'burle', 'bul', 'bule', 'bulen', 'bude', 'dule', 'buhle', 'vule', 'pule', 'buie', 'bele', 'bile', 'buje'}
# Sentence: They saw a bule fish in the lake. | Predicted: blue | Correct: blue
#
# Top BERT Predictions:
# 1. arm
# 2. head
# 3. body
# 4. back
# 5. leg
# 6. shoulder
# 7. face
# 8. chest
# 9. side
# 10. knee
#
# Candidate Words: {'writ', 'wast', 'wst', 'hrst', 'wrist', 'trst', 'irst', 'wost', 'wpst', 'prst', 'rst', 'west', 'krst', 'wgst', 'worst', 'wist', 'wrest', 'wurst', 'erst'}
# Sentence: His wrst was hurting after the fall. | Predicted: west | Correct: wrist
#
# Top BERT Predictions:
# 1. speech
# 2. lecture
# 3. presentation
# 4. talk
# 5. sermon
# 6. class
# 7. test
# 8. lesson
# 9. report
# 10. message
#
# Candidate Words: {'tiz', 'giz', 'liz', 'diz', 'qil', 'qir', 'biz', 'wiz', 'riz', 'niz', 'qizi', 'piz', 'qaz', 'qin', 'iz', 'fiz', 'kiz', 'viz', 'oiz', 'qip', 'quiz', 'qi', 'qia', 'miz', 'qlz', 'qzz', 'qiu', 'aiz'}
# Sentence: The teacher gave a qiz today. | Predicted: qin | Correct: quiz
#
# Top BERT Predictions:
# 1. leather
# 2. light
# 3. heavy
# 4. long
# 5. thick
# 6. wool
# 7. denim
# 8. dark
# 9. black
# 10. thin
#
# Candidate Words: {'sert', 'shri', 'sht', 'sirt', 'sqrt', 'shit', 'short', 'shot', 'hrt', 'shat', 'srt', 'shut', 'surt', 'sort', 'shart', 'shirt', 'smrt', 'sart', 'shxt'}
# Sentence: She wore a shrt jacket in the cold. | Predicted: short | Correct: short
#
# Top BERT Predictions:
# 1. looked
# 2. stared
# 3. glanced
# 4. smiled
# 5. pointed
# 6. glared
# 7. nodded
# 8. frowned
# 9. waved
# 10. stares
#
# Candidate Words: {'pntd', 'punted'}
# Sentence: The little boy pnted at the bird. | Predicted: punted | Correct: pointed
#
# Top BERT Predictions:
# 1. book
# 2. clock
# 3. painting
# 4. lamp
# 5. box
# 6. piano
# 7. letter
# 8. journal
# 9. guitar
# 10. gun
#
# Candidate Words: {'cmix', 'ccic', 'cic', 'smic', 'cmc', 'cmi', 'cmip', 'chic', 'cuic', 'mic', 'cric', 'csic', 'comic'}
# Sentence: He found an old cmic in the attic. | Predicted: comic | Correct: comic
#
# Top BERT Predictions:
# 1. removed
# 2. replaced
# 3. broken
# 4. damaged
# 5. repaired
# 6. crushed
# 7. destroyed
# 8. lost
# 9. split
# 10. cracked
#
# Candidate Words: {'ftl', 'flo', 'rlt', 'xlt', 'mlt', 'flv', 'fat', 'olt', 'lft', 'fla', 'fln', 'fult', 'clt', 'flt', 'fls', 'fet', 'fll', 'fly', 'nlt', 'fdt', 'flq', 'blt', 'flat', 'fst', 'fl', 'llt', 'flu', 'ft', 'lt', 'elt', 'folt', 'flit', 'vlt', 'ult', 'falt', 'fmt', 'felt', 'flm', 'dlt', 'fld', 'wlt', 'fot', 'flk', 'flc', 'fct', 'fit', 'slt', 'fli', 'alt', 'fbt'}
# Sentence: The bike tire was flt after the ride. | Predicted: flat | Correct: flat
#
# Top BERT Predictions:
# 1. piano
# 2. violin
# 3. guitar
# 4. drums
# 5. cello
# 6. bass
# 7. fiddle
# 8. flute
# 9. part
# 10. instrument
#
# Candidate Words: {'guitar', 'gujar', 'guter', 'yutar', 'guar', 'tutar', 'gusar', 'utar', 'gular', 'gubar', 'gstar', 'dutar', 'sutar', 'autar'}
# Sentence: She played the gutar for her friends. | Predicted: guitar | Correct: guitar
#
# Top BERT Predictions:
# 1. full
# 2. empty
# 3. bare
# 4. made
# 5. emptied
# 6. free
# 7. cleared
# 8. composed
# 9. ##ful
# 10. comprised
#
# Candidate Words: {'pul', 'ufl', 'lul', 'fub', 'fun', 'ftl', 'fui', 'fnl', 'fsl', 'rul', 'uul', 'eul', 'fuel', 'fuu', 'fult', 'fuh', 'qul', 'fdl', 'foul', 'full', 'fux', 'fug', 'fcl', 'fhl', 'jul', 'fulc', 'fua', 'fuld', 'vul', 'fll', 'fml', 'wul', 'bul', 'gul', 'fuk', 'faul', 'fuli', 'kul', 'fl', 'flu', 'ful', 'xul', 'fgl', 'fue', 'fol', 'sul', 'oul', 'cul', 'nul', 'fur', 'mul', 'yul', 'fel', 'fula', 'ul', 'fil', 'aul', 'fud', 'fulk', 'fu', 'fal', 'tul', 'fulp'}
# Sentence: The bookcase was ful of old novels. | Predicted: full | Correct: full
#
# Top BERT Predictions:
# 1. deep
# 2. soft
# 3. strong
# 4. beautiful
# 5. low
# 6. high
# 7. quiet
# 8. husky
# 9. booming
# 10. loud
#
# Candidate Words: {'smtp', 'soth', 'smbh', 'seth', 'smith', 'suth', 'smt', 'sith', 'sath', 'smyth', 'smtv'}
# Sentence: He had a smth voice when he spoke. | Predicted: smith | Correct: smooth
#
# Top BERT Predictions:
# 1. cell
# 2. new
# 3. mobile
# 4. cellular
# 5. pay
# 6. smart
# 7. car
# 8. portable
# 9. satellite
# 10. small
#
# Candidate Words: {'nr', 'now', 'uw', 'nj', 'pw', 'nt', 'ni', 'zw', 'nz', 'ww', 'ynw', 'nf', 'cw', 'bw', 'nu', 'wnw', 'ew', 'new', 'gw', 'nsw', 'nrw', 'naw', 'w', 'ne', 'sw', 'nx', 'nk', 'nl', 'nwr', 'na', 'nwt', 'rw', 'nb', 'ns', 'ng', 'nn', 'xw', 'nd', 'ndw', 'nm', 'nc', 'n', 'nnw', 'jw', 'fw', 'lw', 'nv', 'nh', 'mw', 'nw', 'pnw', 'nwa', 'tw', 'dw', 'nwo', 'nws', 'hw', 'nwc', 'nwf', 'ny', 'wn', 'ncw', 'ow', 'vw', 'no', 'aw', 'nwn', 'np', 'kw', 'anw'}
# Sentence: She bought a nw phone yesterday. | Predicted: new | Correct: new
#
# Top BERT Predictions:
# 1. bite
# 2. sip
# 3. swallow
# 4. mouthful
# 5. gulp
# 6. stab
# 7. bites
# 8. slug
# 9. piece
# 10. pull
#
# Candidate Words: {'xit', 'mbit', 'ait', 'kbit', 'nit', 'rit', 'bct', 'bmt', 'bih', 'pit', 'biti', 'bi', 'bitz', 'lit', 'dit', 'bitm', 'obit', 'gbit', 'bilt', 'hit', 'biu', 'bint', 'bith', 'bity', 'bht', 'bot', 'bij', 'yit', 'bwt', 'bip', 'bet', 'but', 'beit', 'git', 'wit', 'biz', 'bxt', 'mit', 'bdt', 'bie', 'bim', 'bita', 'bif', 'ibt', 'it', 'bite', 'bia', 'fit', 'brt', 'bwit', 'bil', 'big', 'ubit', 'biv', 'tit', 'jbit', 'bic', 'bix', 'bt', 'bst', 'cit', 'bid', 'sit', 'bit', 'bjt', 'oit', 'kit', 'jit', 'biot', 'bitt', 'ebit', 'bis', 'bii', 'bhit', 'blt', 'uit', 'bat', 'bir', 'bio', 'bib', 'bait', 'brit', 'birt', 'btt', 'bgt', 'iit', 'qbit', 'bin', 'bist', 'bits', 'abit', 'vit'}
# Sentence: He took a bit of the sandwich. | Predicted: bite | Correct: bite
#
# Top BERT Predictions:
# 1. back
# 2. head
# 3. neck
# 4. arms
# 5. legs
# 6. eyes
# 7. feet
# 8. throat
# 9. face
# 10. body
#
# Candidate Words: {'throb', 'throat', 'tarot', 'tharot', 'trot', 'thot', 'thret', 'thro', 'throw', 'thuot'}
# Sentence: The cold air made my throt sore. | Predicted: throat | Correct: throat
#
# Top BERT Predictions:
# 1. place
# 2. tent
# 3. spot
# 4. site
# 5. camp
# 6. location
# 7. clearing
# 8. room
# 9. trail
# 10. trailer
#
# Candidate Words: {'tnm', 'gnt', 'nt', 'tne', 'txt', 'tont', 'tant', 'tntj', 'tat', 'dnt', 'tot', 'tst', 'tmnt', 'tit', 'tdt', 'tyt', 'tnu', 'tna', 'wnt', 'tns', 'tint', 'tnc', 'tft', 'ont', 'knt', 'ttt', 'tnx', 'tnf', 'tnn', 'tct', 'tng', 'tet', 'tn', 'ant', 'tht', 'tut', 'int', 'tt', 'twt', 'ntt', 'tno', 'cnt', 'ent', 'tnt', 'trt', 'tmt', 'tvt', 'tent', 'tni'}
# Sentence: They set up a tnt for camping. | Predicted: tent | Correct: tent
#
# Top BERT Predictions:
# 1. sand
# 2. dirt
# 3. ground
# 4. snow
# 5. mud
# 6. grass
# 7. soil
# 8. hole
# 9. earth
# 10. water
#
# Candidate Words: {'grond', 'grand', 'gnd', 'grind', 'gend', 'grund', 'gond', 'gund', 'grad', 'rnd', 'grid', 'gand'}
# Sentence: The dog dug in the grnd for its bone. | Predicted: grand | Correct: ground
#
# Top BERT Predictions:
# 1. cowboy
# 2. straw
# 3. top
# 4. santa
# 5. bowler
# 6. black
# 7. big
# 8. white
# 9. red
# 10. baseball
#
# Candidate Words: {'iwl', 'bwa', 'bawl', 'gwl', 'bnl', 'bwt', 'bil', 'bkl', 'blw', 'owl', 'bowl', 'bwv', 'bw', 'bsl', 'bl', 'bwm', 'pwl', 'bdl', 'bal', 'byl', 'bol', 'bul', 'ewl', 'bwo', 'bwi', 'wl', 'bwf', 'bwn', 'awl', 'wbl', 'bcl', 'bel', 'bwh', 'lwl', 'bbl', 'bpl', 'bwbl', 'wwl', 'bwk'}
# Sentence: She wore a bwl hat at the wedding. | Predicted: bowl | Correct: bowler
#
# Top BERT Predictions:
# 1. police
# 2. black
# 3. dark
# 4. cop
# 5. patrol
# 6. white
# 7. small
# 8. squad
# 9. red
# 10. parked
#
# Candidate Words: {'blou', 'bly', 'blux', 'blc', 'lu', 'blue', 'blw', 'bru', 'blu', 'bou', 'clu', 'bl', 'ble', 'bju', 'balu', 'blum', 'glu', 'blt', 'buu', 'bul', 'blau', 'bolu', 'btu', 'byu', 'blun', 'plu', 'bli', 'olu', 'bleu', 'bau', 'ulu', 'belu', 'blut', 'flu', 'klu', 'beu', 'bla', 'bu', 'jlu', 'blp', 'biu', 'bsu', 'blv', 'blm', 'blur', 'bhu', 'mlu', 'blg', 'alu', 'elu', 'bls', 'blk', 'bmu'}
# Sentence: I saw a blu car in the driveway. | Predicted: blue | Correct: blue
#
# Top BERT Predictions:
# 1. empty
# 2. open
# 3. enormous
# 4. aching
# 5. extra
# 6. invisible
# 7. unfamiliar
# 8. unexpected
# 9. uncomfortable
# 10. awkward
#
# Candidate Words: {'imty', 'mty', 'emry', 'nemty', 'etty', 'emmy', 'empty', 'emt', 'emy', 'emts'}
# Sentence: He felt an emty space in his heart. | Predicted: empty | Correct: empty
#
# Top BERT Predictions:
# 1. headache
# 2. seizure
# 3. nightmare
# 4. fever
# 5. cold
# 6. dream
# 7. contraction
# 8. stomach
# 9. lump
# 10. vision
#
# Candidate Words: {'ever', 'uver', 'fever', 'foer', 'fter', 'iver', 'fve', 'fher', 'feer', 'fer', 'fier', 'fler', 'fiver', 'fyer', 'ver', 'over', 'fuer', 'fvr', 'pver', 'vver', 'tver', 'aver', 'faer'}
# Sentence: She had a fver and felt sick. | Predicted: fever | Correct: fever
#
# Top BERT Predictions:
# 1. party
# 2. concert
# 3. show
# 4. bonfire
# 5. rally
# 6. celebration
# 7. festival
# 8. dance
# 9. ceremony
# 10. parade
#
# Candidate Words: {'feast', 'fist', 'feisty', 'fest', 'feist', 'weist', 'geist', 'feidt', 'feiss', 'freist', 'zeist', 'heist', 'faist', 'peist', 'feit', 'frist', 'feint', 'deist', 'feish'}
# Sentence: They held a big feist at the end of the festival. | Predicted: feast | Correct: feast
#
# Top BERT Predictions:
# 1. ran
# 2. flowed
# 3. flows
# 4. runs
# 5. continued
# 6. wound
# 7. echoed
# 8. rolled
# 9. led
# 10. went
#
# Candidate Words: {'flawed', 'flied', 'flowed', 'flued', 'fled'}
# Sentence: The river flwed down the mountain. | Predicted: flowed | Correct: flowed
#
# Top BERT Predictions:
# 1. glass
# 2. cup
# 3. box
# 4. phone
# 5. glasses
# 6. book
# 7. bottle
# 8. coffee
# 9. paper
# 10. plate
#
# Candidate Words: {'spion', 'spoon'}
# Sentence: She put the sppon on the table. | Predicted: spoon | Correct: spoon
#
# Top BERT Predictions:
# 1. long
# 2. short
# 3. thick
# 4. fluffy
# 5. curly
# 6. straight
# 7. soft
# 8. longer
# 9. strong
# 10. thin
#
# Candidate Words: {'kng', 'yng', 'ltg', 'log', 'gng', 'long', 'lng', 'lsg', 'ln', 'png', 'lqg', 'lig', 'lnb', 'leg', 'ung', 'lna', 'ng', 'lngs', 'lug', 'leng', 'lnc', 'ing', 'lag', 'lkg', 'lpg', 'lang', 'tng', 'ling', 'sng', 'lmg', 'lfg', 'lyng', 'nlg', 'lnr', 'nlng', 'lung', 'cng', 'lne', 'eng', 'lnj', 'ang', 'rng', 'mng', 'ong', 'lnp', 'dng', 'lbg', 'lg'}
# Sentence: The cat had soft fur and a lng tail. | Predicted: long | Correct: long
#
# Top BERT Predictions:
# 1. wall
# 2. floor
# 3. door
# 4. building
# 5. structure
# 6. statue
# 7. tower
# 8. house
# 9. altar
# 10. gate
#
# Candidate Words: {'brage', 'bridge', 'badge', 'budge'}
# Sentence: The brdge was made of stone. | Predicted: bridge | Correct: bridge
#
# Top BERT Predictions:
# 1. new
# 2. red
# 3. wool
# 4. silk
# 5. green
# 6. white
# 7. black
# 8. blue
# 9. large
# 10. pink
#
# Candidate Words: {'slk', 'ssk', 'clk', 'glk', 'lsk', 'silk', 'sjk', 'klk', 'sle', 'shk', 'sulk', 'elk', 'slf', 'slok', 'sla', 'ilk', 'ulk', 'sdk', 'sls', 'sik', 'smk', 'slc', 'sld', 'vlk', 'slv', 'mlk', 'alk', 'salk', 'stk', 'slm', 'suk', 'lk', 'slik', 'sek', 'plk', 'sly', 'slo', 'sbk', 'sk', 'sl', 'slb', 'sak', 'sok', 'skk', 'sll', 'slr', 'snk', 'spk', 'flk', 'svk', 'srk', 'sli', 'olk', 'slt', 'blk'}
# Sentence: She bought a slk scarf from the market. | Predicted: silk | Correct: silk
#
# Top BERT Predictions:
# 1. hands
# 2. feet
# 3. fingers
# 4. cheeks
# 5. legs
# 6. arms
# 7. clothes
# 8. palms
# 9. boots
# 10. shoulders
#
# Candidate Words: {'nds', 'hnd', 'hyds', 'bnds', 'ends', 'hrds', 'hns', 'hdds', 'pnds', 'hzds', 'hands', 'hinds', 'ands'}
# Sentence: His hnds were cold from the snow. | Predicted: hands | Correct: hands
#
# Top BERT Predictions:
# 1. dress
# 2. shirt
# 3. skirt
# 4. suit
# 5. jacket
# 6. robe
# 7. coat
# 8. sweater
# 9. top
# 10. fabric
#
# Candidate Words: {'jacket', 'icket'}
# Sentence: The jcket was too tight to wear. | Predicted: jacket | Correct: jacket
#
# Top BERT Predictions:
# 1. steep
# 2. small
# 3. little
# 4. slight
# 5. short
# 6. narrow
# 7. low
# 8. rocky
# 9. gentle
# 10. long
#
# Candidate Words: {'std', 'dtp', 'stc', 'stn', 'ntp', 'tsp', 'stm', 'stx', 'sta', 'sip', 'swp', 'stop', 'ttp', 'ctp', 'srp', 'sep', 'sto', 'sop', 'atp', 'stf', 'ftp', 'spt', 'svp', 'sp', 'tp', 'st', 'sfp', 'stg', 'smp', 'sftp', 'stl', 'utp', 'str', 'ssp', 'stw', 'stk', 'ste', 'ktp', 'ptp', 'sgp', 'sdp', 'sap', 'astp', 'itp', 'sty', 'sup', 'stip', 'stb', 'ostp', 'scp', 'smtp', 'spp', 'otp', 'step', 'ltp', 'sti', 'snp', 'sts', 'stu', 'stv', 'stap', 'sbp', 'stp', 'rtp', 'gtp'}
# Sentence: We hiked up a stp hill. | Predicted: st | Correct: steep
#
# Top BERT Predictions:
# 1. cabin
# 2. house
# 3. hut
# 4. cottage
# 5. camp
# 6. tent
# 7. boat
# 8. shack
# 9. shelter
# 10. canoe
#
# Candidate Words: {'sandcastle'}
# Sentence: The boy built a sndcastle by the shore. | Predicted: sandcastle | Correct: sandcastle
#
# Top BERT Predictions:
# 1. note
# 2. letter
# 3. message
# 4. report
# 5. list
# 6. response
# 7. book
# 8. paper
# 9. story
# 10. newspaper
#
# Candidate Words: {'prem', 'poem', 'aem', 'paer', 'pem', 'pae', 'paek', 'piem', 'haem', 'palm', 'laem', 'panem', 'qaem', 'paes', 'psem', 'paez', 'pacem', 'pam', 'peam', 'caem', 'paea'}
# Sentence: She read a paem to the class. | Predicted: poem | Correct: poem
#
# Top BERT Predictions:
# 1. bread
# 2. food
# 3. coffee
# 4. eggs
# 5. meat
# 6. cakes
# 7. cheese
# 8. cuts
# 9. rolls
# 10. pie
#
# Candidate Words: {'bree', 'brd', 'breda', 'brew', 'bored', 'brid', 'bre', 'breg', 'bren', 'brey', 'bed', 'brend', 'berd', 'bled', 'breed', 'bred', 'vred', 'ered', 'bared', 'bped', 'beed', 'brec', 'bread', 'bsed', 'breo', 'red', 'bured', 'brel', 'dred', 'bres', 'bret', 'brem', 'brede', 'brea', 'fred', 'brod', 'brer', 'bied', 'brez', 'brad', 'bhed'}
# Sentence: The baker made fresh bred every morning. | Predicted: bread | Correct: bread
#
# Top BERT Predictions:
# 1. side
# 2. dirt
# 3. narrow
# 4. gravel
# 5. country
# 6. winding
# 7. deserted
# 8. dark
# 9. quiet
# 10. back
#
# Candidate Words: {'strat', 'strut', 'sert', 'stort', 'srt', 'stat', 'smrt', 'start', 'sart', 'sirt', 'surt', 'trt', 'stri', 'sort', 'sturt', 'sqrt', 'str'}
# Sentence: He drove down a strt road. | Predicted: start | Correct: street
#
# Top BERT Predictions:
# 1. still
# 2. high
# 3. up
# 4. now
# 5. visible
# 6. already
# 7. hovering
# 8. low
# 9. rising
# 10. back
#
# Candidate Words: {'li', 'uw', 'pw', 'lew', 'zw', 'lu', 'ww', 'lx', 'blw', 'cw', 'ln', 'bw', 'lgw', 'lwo', 'ls', 'ew', 'gw', 'plw', 'lp', 'lf', 'w', 'sw', 'lc', 'la', 'rw', 'le', 'll', 'ly', 'xw', 'lj', 'wl', 'lr', 'lwa', 'lwp', 'lwh', 'alw', 'lt', 'jw', 'lwt', 'lk', 'fw', 'lw', 'lz', 'lo', 'lzw', 'mlw', 'mw', 'nw', 'lm', 'lq', 'lbw', 'dw', 'tw', 'lb', 'hw', 'vlw', 'lwl', 'law', 'lh', 'l', 'ow', 'lwf', 'vw', 'aw', 'lv', 'ld', 'wlw', 'low', 'kw', 'lsw', 'lg'}
# Sentence: The plane was lw in the sky. | Predicted: low | Correct: low
#
# Top BERT Predictions:
# 1. small
# 2. sticky
# 3. quick
# 4. folded
# 5. short
# 6. new
# 7. long
# 8. large
# 9. little
# 10. brief
#
# Candidate Words: {'und', 'khd', 'ked', 'kng', 'knm', 'kd', 'mnd', 'kpd', 'kod', 'kid', 'knd', 'ond', 'kbd', 'kyd', 'kind', 'wnd', 'vnd', 'kad', 'kns', 'knu', 'kwd', 'nd', 'kmd', 'end', 'knt', 'knx', 'kund', 'kn', 'kno', 'and', 'kndp', 'rnd', 'ktd', 'knp', 'cnd', 'bnd', 'knud', 'hnd', 'knb', 'gnd', 'kdd', 'knh', 'ind', 'dnd', 'jnd', 'snd', 'kud'}
# Sentence: She found a knd note on her desk. | Predicted: and | Correct: kind
#
# Top BERT Predictions:
# 1. silence
# 2. noise
# 3. sound
# 4. light
# 5. smell
# 6. voices
# 7. screams
# 8. smoke
# 9. stench
# 10. sounds
#
# Candidate Words: {'smk', 'ske', 'smee', 'sme', 'imke', 'seke', 'suke', 'ymke', 'sake', 'smoke'}
# Sentence: The smke filled the room quickly. | Predicted: smoke | Correct: smoke
#
# Top BERT Predictions:
# 1. jacket
# 2. coat
# 3. gun
# 4. hand
# 5. purse
# 6. keys
# 7. bag
# 8. phone
# 9. briefcase
# 10. shoes
#
# Candidate Words: {'clothes'}
# Sentence: He left his clthes on the chair. | Predicted: clothes | Correct: clothes
#
# Top BERT Predictions:
# 1. spilled
# 2. spat
# 3. spit
# 4. poured
# 5. dropped
# 6. put
# 7. left
# 8. threw
# 9. dripped
# 10. smelled
#
# Candidate Words: {'spilled', 'spelled'}
# Sentence: The child splled juice on the floor. | Predicted: spilled | Correct: spilled
#
# Top BERT Predictions:
# 1. pearl
# 2. diamond
# 3. gold
# 4. ruby
# 5. silver
# 6. beautiful
# 7. matching
# 8. white
# 9. purple
# 10. wedding
#
# Candidate Words: {'gulden', 'alden', 'olden', 'goden', 'golden', 'gaden', 'elden', 'glen', 'giden', 'gloden'}
# Sentence: She wore a glden necklace to the party. | Predicted: golden | Correct: golden
#
# Top BERT Predictions:
# 1. door
# 2. picture
# 3. camera
# 4. body
# 5. gun
# 6. man
# 7. bed
# 8. book
# 9. window
# 10. car
#
# Candidate Words: {'canvas', 'covas'}
# Sentence: The cnvas was stretched on the frame. | Predicted: canvas | Correct: canvas
#
# Top BERT Predictions:
# 1. heart
# 2. pulse
# 3. head
# 4. blood
# 5. chest
# 6. heartbeat
# 7. body
# 8. brain
# 9. mind
# 10. throat
#
# Candidate Words: {'heft', 'herk', 'kert', 'sert', 'hett', 'hera', 'hert', 'herr', 'heru', 'hurt', 'herts', 'herut', 'tert', 'pert', 'heri', 'chert', 'hrt', 'mert', 'hero', 'aert', 'herz', 'hers', 'wert', 'hirt', 'herb', 'here', 'hery', 'gert', 'dert', 'helt', 'herc', 'herta', 'hertz', 'herp', 'herti', 'herat', 'herd', 'eert', 'bert', 'fert', 'heat', 'heut', 'herl', 'hern', 'heart', 'hept', 'vert', 'het', 'her', 'cert', 'ert', 'hart', 'hort', 'lert', 'herm'}
# Sentence: His hert was beating fast. | Predicted: heart | Correct: heart
#
# Top BERT Predictions:
# 1. glass
# 2. sip
# 3. bottle
# 4. mouthful
# 5. gulp
# 6. drink
# 7. cup
# 8. swallow
# 9. lot
# 10. bit
#
# Candidate Words: {'gcss', 'gnss', 'gtss', 'glos', 'glis', 'gless', 'gass', 'gliss', 'glsl', 'gloss', 'guss', 'gpss', 'glass', 'glas', 'gss', 'rlss', 'goss', 'gls', 'ghss'}
# Sentence: She drank a glss of water. | Predicted: glass | Correct: glass
#
# Top BERT Predictions:
# 1. crack
# 2. break
# 3. hole
# 4. dent
# 5. gap
# 6. crash
# 7. thud
# 8. noise
# 9. click
# 10. rip
#
# Candidate Words: {'crc', 'crcp', 'cruck', 'crcs', 'crack', 'crock', 'crcl', 'crick', 'cck', 'cock', 'cuck', 'crcn'}
# Sentence: They heard a crck in the wall. | Predicted: crack | Correct: crack
#
# Top BERT Predictions:
# 1. first
# 2. next
# 3. second
# 4. third
# 5. last
# 6. final
# 7. fourth
# 8. fifth
# 9. sixth
# 10. middle
#
# Candidate Words: {'fret', 'forst', 'hrst', 'erst', 'frsl', 'fist', 'furst', 'fost', 'fest', 'frot', 'frost', 'fst', 'frsc', 'trst', 'irst', 'fast', 'frit', 'prst', 'frs', 'rst', 'frsa', 'frist', 'krst', 'first', 'fust', 'frat', 'frse'}
# Sentence: The frst step is the hardest. | Predicted: first | Correct: first
#
# Top BERT Predictions:
# 1. dropped
# 2. tossed
# 3. kicked
# 4. hit
# 5. left
# 6. threw
# 7. caught
# 8. found
# 9. struck
# 10. saw
#
# Candidate Words: {'und', 'fnx', 'frd', 'fnl', 'fnm', 'fhd', 'fund', 'fwd', 'fid', 'fond', 'fod', 'mnd', 'ond', 'knd', 'wnd', 'fbd', 'vnd', 'fdn', 'nd', 'ftd', 'fna', 'end', 'find', 'fvd', 'fn', 'fnv', 'fnc', 'fend', 'and', 'fad', 'rnd', 'fdd', 'fd', 'fand', 'cnd', 'bnd', 'fnb', 'fed', 'hnd', 'fld', 'gnd', 'fmd', 'ind', 'fud', 'dnd', 'jnd', 'snd', 'fynd'}
# Sentence: He fnd a penny on the sidewalk. | Predicted: and | Correct: found
#
# Top BERT Predictions:
# 1. lips
# 2. eyes
# 3. cheeks
# 4. hands
# 5. nails
# 6. sheets
# 7. tips
# 8. scales
# 9. edges
# 10. fingers
#
# Candidate Words: {'bricks', 'bucks', 'backs', 'becks', 'bracks', 'braks'}
# Sentence: The brcks were red and rough. | Predicted: bricks | Correct: bricks
#
# Top BERT Predictions:
# 1. job
# 2. car
# 3. virginity
# 4. mother
# 5. purse
# 6. bike
# 7. clothes
# 8. hair
# 9. sister
# 10. baby
#
# Candidate Words: {'handbag'}
# Sentence: She lost her hndbag at the mall. | Predicted: handbag | Correct: handbag
#
# Top BERT Predictions:
# 1. shone
# 2. burned
# 3. was
# 4. blazed
# 5. glowed
# 6. gleamed
# 7. rose
# 8. hung
# 9. sparkled
# 10. sat
#
# Candidate Words: {'shen', 'shane', 'shwe', 'shae', 'shine', 'sane', 'sine', 'sene', 'shoe', 'shone', 'she', 'syne', 'shyne', 'ihne', 'sune', 'shee', 'shue', 'ohne', 'sone', 'sne'}
# Sentence: The sun shne brightly in the sky. | Predicted: shone | Correct: shone
#
# Top BERT Predictions:
# 1. glasses
# 2. glass
# 3. plates
# 4. drinks
# 5. food
# 6. box
# 7. coffee
# 8. cards
# 9. bottle
# 10. book
#
# Candidate Words: {'lmp', 'tmp', 'mlp', 'lfp', 'ltmp', 'fmp', 'mmp', 'lup', 'lbp', 'lep', 'cmp', 'ldp', 'lpm', 'lp', 'imp', 'llp', 'lmn', 'lmr', 'lmm', 'lms', 'smp', 'mp', 'limp', 'lamp', 'lma', 'lump', 'lmb', 'lwp', 'jmp', 'hmp', 'amp', 'lmu', 'lm', 'lmg', 'bmp', 'lpp', 'lmc', 'ump', 'lop', 'dmp', 'lemp', 'lmpd', 'ltp', 'lme', 'lmd', 'emp', 'lnp', 'gmp', 'lap', 'lip'}
# Sentence: They put the lmp on the table. | Predicted: mp | Correct: lamp
#
# Top BERT Predictions:
# 1. work
# 2. poetry
# 3. art
# 4. writing
# 5. style
# 6. music
# 7. talent
# 8. performance
# 9. teaching
# 10. artwork
#
# Candidate Words: {'wsk', 'ark', 'irk', 'wra', 'wk', 'work', 'wuk', 'dwrk', 'wurk', 'krk', 'wok', 'wre', 'prk', 'wark', 'wik', 'hrk', 'werk', 'wyk', 'wrks', 'wro', 'wwk', 'brk', 'urk', 'nrk', 'wpk', 'ork', 'wrc', 'wrx', 'wrki', 'wak', 'wrl', 'srk', 'rk', 'wek', 'wr', 'wrz', 'wkrk', 'wri', 'wrd', 'wry'}
# Sentence: His wrk was admired by many. | Predicted: work | Correct: work
#
# Top BERT Predictions:
# 1. breath
# 2. moment
# 3. sip
# 4. look
# 5. minute
# 6. second
# 7. bite
# 8. drink
# 9. seat
# 10. shower
#
# Candidate Words: {'birth', 'both', 'arth', 'beth', 'orth', 'borth', 'brith', 'broth', 'barth', 'brts', 'bth', 'bruh', 'brih', 'krth', 'bath', 'byrth', 'berth', 'bith', 'brtn', 'erth', 'brt', 'rth'}
# Sentence: She took a brth before diving in. | Predicted: both | Correct: breath
#
# Top BERT Predictions:
# 1. door
# 2. window
# 3. mirror
# 4. hole
# 5. hatch
# 6. camera
# 7. dent
# 8. cabin
# 9. handle
# 10. bar
#
# Candidate Words: {'dant', 'dft', 'gnt', 'dut', 'nt', 'dbt', 'drt', 'dct', 'dat', 'dnmt', 'dst', 'dt', 'dot', 'dent', 'dnt', 'dnp', 'det', 'dnb', 'dnq', 'dont', 'wnt', 'ddt', 'ndt', 'dnf', 'knt', 'dmt', 'ont', 'dit', 'dni', 'dnc', 'dwt', 'ant', 'dgt', 'dns', 'int', 'dnm', 'dlt', 'dna', 'dtt', 'dint', 'cnt', 'dntf', 'dny', 'dpt', 'tnt', 'dvt', 'ent', 'dnd', 'dnl', 'dng', 'dn', 'dht'}
# Sentence: The car had a dnt on the side. | Predicted: dent | Correct: dent
#
# Top BERT Predictions:
# 1. can
# 2. bottle
# 3. glass
# 4. cup
# 5. liter
# 6. container
# 7. pitcher
# 8. cans
# 9. drink
# 10. bag
#
# Candidate Words: {'rn', 'cnh', 'cz', 'ln', 'gcn', 'cin', 'cgn', 'yn', 'cj', 'cnj', 'n', 'cbn', 'cen', 'cn', 'tcn', 'cpn', 'cf', 'cng', 'cb', 'cd', 'ca', 'c', 'cni', 'vn', 'acn', 'xn', 'ucn', 'gn', 'cw', 'on', 'co', 'hcn', 'cg', 'ci', 'cnb', 'pn', 'fn', 'cnu', 'tn', 'pcn', 'lcn', 'cl', 'cu', 'kcn', 'cnt', 'cnp', 'nn', 'bn', 'cdn', 'con', 'cq', 'ctn', 'en', 'cy', 'cm', 'cs', 'cvn', 'ck', 'sn', 'cnd', 'wn', 'bcn', 'cnv', 'cnr', 'cne', 'cmn', 'cno', 'cna', 'cyn', 'qn', 'cr', 'ocn', 'scn', 'ct', 'in', 'fcn', 'cv', 'nc', 'ch', 'zn', 'kn', 'ce', 'cny', 'un', 'can', 'cnc', 'hn', 'cc', 'rcn', 'an', 'cp', 'cns', 'icn', 'jn', 'cx', 'csn', 'cnn', 'dn', 'mn'}
# Sentence: He held a cn of soda in his hand. | Predicted: can | Correct: can
#
# Top BERT Predictions:
# 1. small
# 2. large
# 3. black
# 4. big
# 5. tiny
# 6. huge
# 7. heavy
# 8. little
# 9. leather
# 10. clutch
#
# Candidate Words: {'block', 'bleck', 'blak', 'back', 'blick', 'buck', 'blc', 'blok', 'balck', 'beck', 'bock', 'black', 'blik', 'blek', 'blk'}
# Sentence: She had a blck purse with her. | Predicted: black | Correct: black
#
# Top BERT Predictions:
# 1. ground
# 2. floor
# 3. table
# 4. grass
# 5. bed
# 6. tree
# 7. wall
# 8. garden
# 9. room
# 10. vase
#
# Candidate Words: {'vld', 'flo', 'wfld', 'frd', 'fhd', 'fwd', 'fold', 'eld', 'fid', 'flv', 'qld', 'fod', 'fla', 'fln', 'flad', 'flt', 'fdl', 'fls', 'fald', 'flds', 'fll', 'fbd', 'tld', 'fly', 'old', 'feld', 'fuld', 'flq', 'jld', 'flod', 'ald', 'ftd', 'fl', 'sld', 'flu', 'fvd', 'uld', 'lld', 'fad', 'fdd', 'fd', 'pld', 'flm', 'fed', 'fld', 'fmd', 'flk', 'flc', 'ld', 'fud', 'nld', 'fli', 'fled'}
# Sentence: The fld was covered in flowers. | Predicted: old | Correct: field
#
# Top BERT Predictions:
# 1. beautiful
# 2. nice
# 3. small
# 4. big
# 5. bright
# 6. lovely
# 7. charming
# 8. sweet
# 9. brilliant
# 10. warm
#
# Candidate Words: {'lavely', 'lely', 'lovely', 'lively'}
# Sentence: The girl had a lvely smile. | Predicted: lovely | Correct: lovely
#
# Top BERT Predictions:
# 1. hill
# 2. mountain
# 3. stairs
# 4. steps
# 5. wall
# 6. cliff
# 7. tower
# 8. cliffs
# 9. ridge
# 10. ladder
#
# Candidate Words: {'sil', 'hils', 'bhil', 'hib', 'shil', 'hif', 'hip', 'uil', 'hir', 'hij', 'pil', 'hih', 'hail', 'hilo', 'hid', 'hit', 'ail', 'ril', 'hql', 'wil', 'fil', 'dhil', 'hilm', 'hii', 'hio', 'hiv', 'nil', 'hfl', 'hvl', 'hnl', 'hix', 'hial', 'kil', 'eil', 'khil', 'hal', 'hll', 'lil', 'heil', 'hilt', 'hi', 'hila', 'bil', 'hsl', 'his', 'hill', 'gil', 'jil', 'il', 'htl', 'oil', 'jhil', 'vil', 'hol', 'ihl', 'dil', 'hcl', 'hin', 'cil', 'mil', 'hil', 'til', 'hl', 'zil', 'hic', 'him', 'hel', 'chil', 'qil', 'phil', 'ghil', 'hiu', 'hie', 'hild', 'thil', 'hkl', 'hdl'}
# Sentence: They climbed the hil before sunset. | Predicted: hill | Correct: hill
#
# Top BERT Predictions:
# 1. frame
# 2. structure
# 3. body
# 4. base
# 5. tower
# 6. bell
# 7. building
# 8. roof
# 9. statue
# 10. church
#
# Candidate Words: {'cmr', 'chf', 'ctr', 'cht', 'cur', 'cir', 'cvr', 'hcr', 'chm', 'lhr', 'chl', 'cr', 'cyr', 'chi', 'cqr', 'chx', 'che', 'chur', 'car', 'chk', 'xchr', 'chc', 'char', 'chd', 'hr', 'ihr', 'nhr', 'cher', 'cha', 'thr', 'echr', 'chp', 'cho', 'chr', 'cfr', 'phr', 'ch', 'chs', 'dhr', 'hhr', 'cor', 'chir', 'cbr', 'clr', 'chor', 'chu', 'cer', 'ohr', 'bhr', 'chb', 'jhr', 'bchr', 'cnr', 'csr', 'chy', 'ahr', 'cpr', 'chri', 'chh', 'cdr', 'chrf', 'ehr', 'ccr'}
# Sentence: The chr was made of wood. | Predicted: car | Correct: chair
#
# Top BERT Predictions:
# 1. sigh
# 2. breath
# 3. cry
# 4. sound
# 5. groan
# 6. laugh
# 7. moan
# 8. grunt
# 9. sob
# 10. gasp
#
# Candidate Words: {'igh', 'sbh', 'sgr', 'sdh', 'suh', 'sugh', 'shh', 'mgh', 'sgl', 'sgh', 'sigh', 'sph', 'hgh', 'gsh', 'sgf', 'sga', 'soh', 'sch', 'snh', 'sgg', 'sgi', 'sgb', 'zgh', 'sg', 'seh', 'sgv', 'srh', 'sgp', 'sge', 'svh', 'gh', 'sgc', 'ssh', 'pgh', 'sgd', 'sh', 'bgh', 'sah', 'sgs', 'shg', 'sgx', 'sih', 'sgt'}
# Sentence: She let out a sgh of relief. | Predicted: sigh | Correct: sigh
#
# Top BERT Predictions:
# 1. village
# 2. town
# 3. fort
# 4. city
# 5. castle
# 6. settlement
# 7. site
# 8. station
# 9. community
# 10. capital
#
# Candidate Words: {'form', 'nrm', 'fr', 'fcm', 'fmr', 'frd', 'fnm', 'fgm', 'urm', 'jrm', 'fsm', 'ffm', 'drm', 'lrm', 'arm', 'fom', 'irm', 'fry', 'ftm', 'furm', 'fhm', 'fdm', 'fru', 'brm', 'frc', 'fri', 'crm', 'grm', 'vrm', 'fam', 'hrm', 'fim', 'farm', 'prm', 'fem', 'fra', 'rm', 'frg', 'flm', 'from', 'srm', 'frim', 'ferm', 'fram', 'fm', 'frp', 'firm', 'erm', 'orm', 'frs', 'fro'}
# Sentence: The frm was located in the valley. | Predicted: from | Correct: farm
#
# Top BERT Predictions:
# 1. knock
# 2. pounding
# 3. rap
# 4. banging
# 5. knocking
# 6. hammering
# 7. tapping
# 8. bang
# 9. voice
# 10. grip
#
# Candidate Words: {'knik', 'kck', 'kock', 'keck', 'knak', 'kuck', 'knack', 'knick', 'kick', 'kack', 'knock'}
# Sentence: His knck on the door was loud. | Predicted: knock | Correct: knock
#
# Top BERT Predictions:
# 1. page
# 2. word
# 3. letter
# 4. note
# 5. line
# 6. chapter
# 7. phrase
# 8. poem
# 9. paragraph
# 10. clause
#
# Candidate Words: {'uge', 'cge', 'page', 'mge', 'pdge', 'jge', 'pse', 'pgc', 'age', 'dge', 'pgce', 'cpge', 'gpe', 'ige', 'vge', 'phe', 'pgt', 'pae', 'pg', 'pgp', 'ppe', 'pgr', 'pgn', 'pie', 'pgd', 'poe', 'pte', 'ege', 'pga', 'tge', 'pee', 'pre', 'pne', 'pige', 'sge', 'pe', 'pde', 'pye', 'pue', 'ple', 'pgl', 'pgs', 'oge', 'pbe', 'pgh', 'ge', 'pgm', 'pce', 'peg', 'pgu', 'pve', 'pxe'}
# Sentence: She found a pge missing from the book. | Predicted: page | Correct: page
#
# Top BERT Predictions:
# 1. degree
# 2. doctorate
# 3. career
# 4. background
# 5. major
# 6. phd
# 7. future
# 8. minor
# 9. father
# 10. masters
#
# Candidate Words: {'pression', 'profession'}
# Sentence: He had a prfession in law. | Predicted: profession | Correct: profession
#
# Top BERT Predictions:
# 1. warm
# 2. tingling
# 3. cold
# 4. strange
# 5. cool
# 6. burning
# 7. odd
# 8. numb
# 9. familiar
# 10. icy
#
# Candidate Words: {'mb', 'nmn', 'nmt', 'ncb', 'npb', 'nsb', 'cmb', 'nmr', 'nmg', 'nmb', 'nbb', 'tmb', 'vmb', 'gmb', 'umb', 'smb', 'amb', 'nmbs', 'dmb', 'nmh', 'ndb', 'nb', 'nmvb', 'imb', 'fmb', 'nlb', 'neb', 'nm', 'pmb', 'lmb', 'nml', 'omb', 'nfb', 'numb', 'nob', 'nmi', 'nib', 'nab', 'nme', 'nmbr', 'emb', 'nms', 'rmb', 'ntb'}
# Sentence: The nmb feeling in his hand was strange. | Predicted: numb | Correct: numb
#
# Top BERT Predictions:
# 1. silent
# 2. quick
# 3. direct
# 4. simple
# 5. short
# 6. clear
# 7. straight
# 8. vague
# 9. quiet
# 10. soft
#
# Candidate Words: {'dyct', 'dect', 'drc', 'krct', 'rct', 'dct', 'drcm', 'drt', 'dact', 'duct', 'drat'}
# Sentence: She gave a drct answer to the question. | Predicted: duct | Correct: direct
#
# Top BERT Predictions:
# 1. on
# 2. from
# 3. and
# 4. in
# 5. at
# 6. off
# 7. ,
# 8. onto
# 9. by
# 10. to
#
# Candidate Words: {'scratched'}
# Sentence: The cat scrtched the couch. | Predicted: scratched | Correct: scratched
#
# Top BERT Predictions:
# 1. opportunity
# 2. excuse
# 3. assignment
# 4. order
# 5. allowance
# 6. offer
# 7. exemption
# 8. incentive
# 9. invitation
# 10. option
#
# Candidate Words: {'opportunity'}
# Sentence: He was given an opporunity to travel. | Predicted: opportunity | Correct: opportunity
#
# Top BERT Predictions:
# 1. name
# 2. notes
# 3. thoughts
# 4. thesis
# 5. own
# 6. comments
# 7. work
# 8. report
# 9. story
# 10. poems
#
# Candidate Words: {'signature'}
# Sentence: She wrote her signture on the form. | Predicted: signature | Correct: signature
#
# Top BERT Predictions:
# 1. hole
# 2. breach
# 3. gap
# 4. crack
# 5. opening
# 6. gate
# 7. door
# 8. damage
# 9. dent
# 10. window
#
# Candidate Words: {'future', 'facture'}
# Sentence: The fcture in the wall was repaired. | Predicted: future | Correct: fracture
#
# ----------- Overall Accuracy -----------
# 73/97 (75.26%)

# %%
import re
from collections import Counter

def words(text):
    return re.findall(r'\w+', text.lower())

def load_corpus(file_path='/kaggle/input/big-text/big.txt'):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

def word_probabilities(word_counts):
    total_words = sum(word_counts.values())
    return {word: count / total_words for word, count in word_counts.items()}

def edits1(word):
    letters = 'abcdefghijklmnopqrstuvwxyz'
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [L + R[1:] for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
    replaces = [L + c + R[1:] for L, R in splits if R for c in letters]
    inserts = [L + c + R for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word):
    return {e2 for e1 in edits1(word) for e2 in edits1(e1)}

def known(words, word_counts):
    return {word for word in words if word in word_counts}

def correct(word, word_counts, word_probs):
    candidates = (known([word], word_counts) or
                  known(edits1(word), word_counts) or
                  known(edits2(word), word_counts) or
                  [word])
    return max(candidates, key=word_probs.get)

if __name__ == '__main__':
    corpus = load_corpus('/kaggle/input/big-text/big.txt')
    word_counts = Counter(words(corpus))
    word_probs = word_probabilities(word_counts)
    
    misspelled_word = 'speling'
    correction = correct(misspelled_word, word_counts, word_probs)
    print(f"Correction for '{misspelled_word}': {correction}")
# Out:
# Correction for 'speling': spelling

# %%
eval_data = load_eval_dataset('/kaggle/input/eval-ambiguous/eval.txt')

def evaluate_norvig_model(eval_data):
    correct_total = 0
    total = 0

    for case in eval_data:
        predicted = correct(case['misspelled'], word_counts, word_probs)
        print(f"Sentence: {case['sentence']} | Predicted: {predicted} | Correct: {case['correct']}")

        total += 1

        if predicted == case['correct']:
            correct_total += 1

    overall_accuracy = correct_total / total if total > 0 else 0

    print(f"\n{' Overall Accuracy ':-^40}")
    print(f"{correct_total}/{total} ({overall_accuracy:.2%})\n")

evaluate_norvig_model(eval_data)
# Out:
# Sentence: The car drve fast on the highway. | Predicted: drove | Correct: drove
# Sentence: She saw a brid flying in the sky. | Predicted: rid | Correct: bird
# Sentence: He used a pencl to write notes. | Predicted: pencil | Correct: pencil
# Sentence: They found a brwn puppy in the park. | Predicted: brown | Correct: brown
# Sentence: My friend brke his phone screen. | Predicted: broke | Correct: broke
# Sentence: The dog dug a hol in the yard. | Predicted: how | Correct: hole
# Sentence: She wore a yelow dress to the party. | Predicted: below | Correct: yellow
# Sentence: I heard a lod noise outside. | Predicted: old | Correct: loud
# Sentence: The old man had a wlk in the garden. | Predicted: walk | Correct: walk
# Sentence: We took a bote to the island. | Predicted: bone | Correct: boat
# Sentence: His glss broke when it fell. | Predicted: glass | Correct: glass
# Sentence: She drew a smal picture in her notebook. | Predicted: small | Correct: small
# Sentence: The fire brnt the wood completely. | Predicted: bent | Correct: burnt
# Sentence: The child liks to play in the park. | Predicted: like | Correct: likes
# Sentence: She had a hrd time solving the puzzle. | Predicted: had | Correct: hard
# Sentence: The storm clsed all the roads. | Predicted: closed | Correct: closed
# Sentence: We saw a bwl of fruit on the table. | Predicted: bowl | Correct: bowl
# Sentence: She put a buk on the shelf. | Predicted: but | Correct: book
# Sentence: The cat jumpd onto the windowsill. | Predicted: jumped | Correct: jumped
# Sentence: He set the clock to wke him early. | Predicted: we | Correct: wake
# Sentence: They sent a lter to their cousin. | Predicted: later | Correct: letter
# Sentence: I ate a bow of soup for lunch. | Predicted: bow | Correct: bowl
# Sentence: He left his cke on the table. | Predicted: ce | Correct: cake
# Sentence: She saw a bech covered in seashells. | Predicted: bench | Correct: beach
# Sentence: The child clmbed the tree. | Predicted: climbed | Correct: climbed
# Sentence: He spent his evning watching TV. | Predicted: evening | Correct: evening
# Sentence: She made a brad sandwich. | Predicted: bad | Correct: bread
# Sentence: The baby crwed across the floor. | Predicted: cried | Correct: crawled
# Sentence: The kite flw high in the sky. | Predicted: few | Correct: flew
# Sentence: They saw a bule fish in the lake. | Predicted: blue | Correct: blue
# Sentence: His wrst was hurting after the fall. | Predicted: west | Correct: wrist
# Sentence: The teacher gave a qiz today. | Predicted: wiz | Correct: quiz
# Sentence: She wore a shrt jacket in the cold. | Predicted: short | Correct: short
# Sentence: The little boy pnted at the bird. | Predicted: panted | Correct: pointed
# Sentence: He found an old cmic in the attic. | Predicted: comic | Correct: comic
# Sentence: The bike tire was flt after the ride. | Predicted: felt | Correct: flat
# Sentence: She played the gutar for her friends. | Predicted: guitar | Correct: guitar
# Sentence: The bookcase was ful of old novels. | Predicted: full | Correct: full
# Sentence: He had a smth voice when he spoke. | Predicted: smith | Correct: smooth
# Sentence: She bought a nw phone yesterday. | Predicted: no | Correct: new
# Sentence: He took a bit of the sandwich. | Predicted: bit | Correct: bite
# Sentence: The cold air made my throt sore. | Predicted: throat | Correct: throat
# Sentence: They set up a tnt for camping. | Predicted: tent | Correct: tent
# Sentence: The dog dug in the grnd for its bone. | Predicted: grand | Correct: ground
# Sentence: She wore a bwl hat at the wedding. | Predicted: bowl | Correct: bowler
# Sentence: I saw a blu car in the driveway. | Predicted: blue | Correct: blue
# Sentence: He felt an emty space in his heart. | Predicted: empty | Correct: empty
# Sentence: She had a fver and felt sick. | Predicted: over | Correct: fever
# Sentence: They held a big feist at the end of the festival. | Predicted: feast | Correct: feast
# Sentence: The river flwed down the mountain. | Predicted: fled | Correct: flowed
# Sentence: She put the sppon on the table. | Predicted: spoon | Correct: spoon
# Sentence: The cat had soft fur and a lng tail. | Predicted: long | Correct: long
# Sentence: The brdge was made of stone. | Predicted: bridge | Correct: bridge
# Sentence: She bought a slk scarf from the market. | Predicted: silk | Correct: silk
# Sentence: His hnds were cold from the snow. | Predicted: hands | Correct: hands
# Sentence: The jcket was too tight to wear. | Predicted: jacket | Correct: jacket
# Sentence: We hiked up a stp hill. | Predicted: st | Correct: steep
# Sentence: The boy built a sndcastle by the shore. | Predicted: sndcastle | Correct: sandcastle
# Sentence: She read a paem to the class. | Predicted: palm | Correct: poem
# Sentence: The baker made fresh bred every morning. | Predicted: bred | Correct: bread
# Sentence: He drove down a strt road. | Predicted: sort | Correct: street
# Sentence: The plane was lw in the sky. | Predicted: law | Correct: low
# Sentence: She found a knd note on her desk. | Predicted: and | Correct: kind
# Sentence: The smke filled the room quickly. | Predicted: smoke | Correct: smoke
# Sentence: He left his clthes on the chair. | Predicted: clothes | Correct: clothes
# Sentence: The child splled juice on the floor. | Predicted: spilled | Correct: spilled
# Sentence: She wore a glden necklace to the party. | Predicted: golden | Correct: golden
# Sentence: The cnvas was stretched on the frame. | Predicted: canvas | Correct: canvas
# Sentence: His hert was beating fast. | Predicted: her | Correct: heart
# Sentence: She drank a glss of water. | Predicted: glass | Correct: glass
# Sentence: They heard a crck in the wall. | Predicted: crack | Correct: crack
# Sentence: The frst step is the hardest. | Predicted: first | Correct: first
# Sentence: He fnd a penny on the sidewalk. | Predicted: and | Correct: found
# Sentence: The brcks were red and rough. | Predicted: backs | Correct: bricks
# Sentence: She lost her hndbag at the mall. | Predicted: sandbag | Correct: handbag
# Sentence: The sun shne brightly in the sky. | Predicted: she | Correct: shone
# Sentence: They put the lmp on the table. | Predicted: lip | Correct: lamp
# Sentence: His wrk was admired by many. | Predicted: work | Correct: work
# Sentence: She took a brth before diving in. | Predicted: both | Correct: breath
# Sentence: The car had a dnt on the side. | Predicted: dint | Correct: dent
# Sentence: He held a cn of soda in his hand. | Predicted: in | Correct: can
# Sentence: She had a blck purse with her. | Predicted: back | Correct: black
# Sentence: The fld was covered in flowers. | Predicted: old | Correct: field
# Sentence: The girl had a lvely smile. | Predicted: lovely | Correct: lovely
# Sentence: They climbed the hil before sunset. | Predicted: his | Correct: hill
# Sentence: The chr was made of wood. | Predicted: cher | Correct: chair
# Sentence: She let out a sgh of relief. | Predicted: sigh | Correct: sigh
# Sentence: The frm was located in the valley. | Predicted: from | Correct: farm
# Sentence: His knck on the door was loud. | Predicted: knock | Correct: knock
# Sentence: She found a pge missing from the book. | Predicted: age | Correct: page
# Sentence: He had a prfession in law. | Predicted: profession | Correct: profession
# Sentence: The nmb feeling in his hand was strange. | Predicted: mb | Correct: numb
# Sentence: She gave a drct answer to the question. | Predicted: duct | Correct: direct
# Sentence: The cat scrtched the couch. | Predicted: scratched | Correct: scratched
# Sentence: He was given an opporunity to travel. | Predicted: opportunity | Correct: opportunity
# Sentence: She wrote her signture on the form. | Predicted: signature | Correct: signature
# Sentence: The fcture in the wall was repaired. | Predicted: future | Correct: fracture
#
# ----------- Overall Accuracy -----------
# 44/97 (45.36%)

# %% [markdown]
# As it can be seen, BERT-based solution makes much better and explainable solutions resulting in 75% of accuracy and can be further finetuned for specific needs for example assigning higher probabilities to words frequently typed by a user, while baseline Norvig's solution has only 45% of accuracy and quite limited by it, since it cannot get the semantics and context of a typed sentence.

# %% [markdown]
# #### Useful resources (also included in the archive in moodle):
#
# 1. [Possible dataset with N-grams](https://www.ngrams.info/download_coca.asp)
# 2. [Damerau–Levenshtein distance](https://en.wikipedia.org/wiki/Damerau–Levenshtein_distance#:~:text=Informally%2C%20the%20Damerau–Levenshtein%20distance,one%20word%20into%20the%20other.)
